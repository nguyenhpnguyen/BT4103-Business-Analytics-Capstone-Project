# %% [markdown]
# # Data Cleaning
#
# * Data used: *"China HRC Price Model - Edited Combined Data.csv"*

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %%
## use this part, if you are using google colab
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## Data Loading

# %%
# Load the data and check the first few lines
dataset_path = "../data/raw/China HRC Price Model - Edited Combined Data.csv"
df = pd.read_csv(dataset_path)
df.head()
# Out:
#     Month  HRC \r\n(FOB, $/t)  Iron Ore \r\n(CFR, $/t)  \
# 0  Jan-06                 388                       47
# 1  Feb-06                 388                       48
# 2  Mar-06                 449                       50
# 3  Apr-06                 478                       57
# 4  May-06                 505                       56
#
#    HCC \r\n(Aus FOB, $/t)  Domestic Scrap (DDP Jiangsu incl. VAT $/t)  \
# 0                     125                                         248
# 1                     125                                         248
# 2                     125                                         251
# 3                     116                                         257
# 4                     116                                         263
#
#    RM Cost \r\n($/t)  HRC - RM \r\nSpread ($/t)  CS Production (Mnt)  \
# 0                200                        187                 30.0
# 1                202                        185                 30.0
# 2                205                        244                 33.0
# 3                207                        271                 35.0
# 4                205                        300                 36.0
#
#    Exports \r\n(Mnt)  Imports \r\n(Mnt)  Net Exports (Mnt)  \
# 0                2.0                2.0                0.0
# 1                2.0                1.0                1.0
# 2                3.0                2.0                1.0
# 3                3.0                2.0                1.0
# 4                4.0                2.0                3.0
#
#   Export as % of Production Cummulative FAI growth (%)  ACSU \r\n(Mnt)  \
# 0                        7%                     26.60%            30.0
# 1                        7%                     26.60%            29.0
# 2                        9%                     29.80%            32.0
# 3                        9%                     29.60%            33.0
# 4                       12%                     30.30%            33.0
#
#    Monthly Imports of semis & finished steel (Mt.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   YTD Growth rate of  Investment  (Fixed asset investment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Fixed asset investment in real estate development in urban areas (y-o-y )Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Floor space under construction (y-o-y) Automobile Production (y-o-y)  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
#   Civil Metal-Vessels/Steel Ships (y-o-y) Household Fridges (y-o-y)  \
# 0                                     NaN                       NaN
# 1                                     NaN                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
#
#   Air Conditioner (y-o-y) Manufacturing PMI for steel
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN

# %%
df.columns
# Out:
# Index(['Month', 'HRC \r\n(FOB, $/t)', 'Iron Ore \r\n(CFR, $/t)',
#        'HCC \r\n(Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'RM Cost \r\n($/t)', 'HRC - RM \r\nSpread ($/t)', 'CS Production (Mnt)',
#        'Exports \r\n(Mnt)', 'Imports \r\n(Mnt)', 'Net Exports (Mnt)',
#        'Export as % of Production', 'Cummulative FAI growth (%)',
#        'ACSU \r\n(Mnt)', 'Monthly Imports of semis & finished steel (Mt.)',
#        'Monthly Export of semis & finished steel (Mt.)',
#        'Monthly Iron ore Imports (Mt.)', 'YTD Iron ore Imports (Mt.)',
#        'YTD Iron ore Production (Mt.)', 'Monthly Iron ore Production (Mt.)',
#        'Stocks of iron ore at China's seaport (Mt.)',
#        'YTD Growth rate of  Investment  (Fixed asset investment)',
#        'Fixed asset investment in real estate development in urban areas (y-o-y )Growth',
#        'Floor space under construction (y-o-y)',
#        'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
#        'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel'],
#       dtype='object')

# %%
df.rename(columns={'HRC \r\n(FOB, $/t)':'HRC (FOB, $/t)', 'Iron Ore \r\n(CFR, $/t)': 'Iron Ore (CFR, $/t)',
                   'HCC \r\n(Aus FOB, $/t)': 'HCC (Aus FOB, $/t)', 'RM Cost \r\n($/t)': 'RM Cost ($/t)',
                   'HRC - RM \r\nSpread ($/t)': 'HRC - RM Spread ($/t)', 'Exports \r\n(Mnt)': 'Exports (Mnt)',
                   'Imports \r\n(Mnt)': 'Imports (Mnt)', 'ACSU \r\n(Mnt)': 'ACSU (Mnt)',
                   'YTD Growth rate of  Investment  (Fixed asset investment)': 'YTD Growth rate of Investment (FAI)',
                   'Fixed asset investment in real estate development in urban areas (y-o-y )Growth':
                       'FAI in urban real estate development (y-o-y) Growth'},
          inplace=True)

# %% [markdown]
# ## Data Check
# * Missing data in columns.
# * Duplicates.
# * Data types.

# %%
df.isnull().sum()
# Out:
# Month                                                   0
# HRC (FOB, $/t)                                          0
# Iron Ore (CFR, $/t)                                     0
# HCC (Aus FOB, $/t)                                      0
# Domestic Scrap (DDP Jiangsu incl. VAT $/t)              0
# RM Cost ($/t)                                           0
# HRC - RM Spread ($/t)                                   0
# CS Production (Mnt)                                     1
# Exports (Mnt)                                           1
# Imports (Mnt)                                           1
# Net Exports (Mnt)                                       1
# Export as % of Production                               1
# Cummulative FAI growth (%)                              4
# ACSU (Mnt)                                              3
# Monthly Imports of semis & finished steel (Mt.)        20
# Monthly Export of semis & finished steel (Mt.)         24
# Monthly Iron ore Imports (Mt.)                         33
# YTD Iron ore Imports (Mt.)                             38
# YTD Iron ore Production (Mt.)                          32
# Monthly Iron ore Production (Mt.)                      45
# Stocks of iron ore at China's seaport (Mt.)            15
# YTD Growth rate of Investment (FAI)                    23
# FAI in urban real estate development (y-o-y) Growth    22
# Floor space under construction (y-o-y)                 79
# Automobile Production (y-o-y)                          19
# Civil Metal-Vessels/Steel Ships (y-o-y)                32
# Household Fridges (y-o-y)                              44
# Air Conditioner (y-o-y)                                34
# Manufacturing PMI for steel                            13
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Convert `str` to numeric
# As some column values are in string format with percentage sign (%), we delete the sign and convert them to float format.

# %%
# Check for columns with string values
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Month', 'Export as % of Production', 'Cummulative FAI growth (%)',
#        'YTD Growth rate of Investment (FAI)',
#        'FAI in urban real estate development (y-o-y) Growth',
#        'Floor space under construction (y-o-y)',
#        'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
#        'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel'],
#       dtype='object')

# %%
# Delete % sign from column values
col_w_perc = df.dtypes[df.dtypes == 'object'].index

for col in col_w_perc:
    if col == 'Month':
        continue
    df[col] = df[col].apply(lambda x: str(x).rstrip('%') if isinstance(x, str) else x)
    df[col] = pd.to_numeric(df[col])

df.head()
# Out:
#     Month  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0  Jan-06             388                   47                 125
# 1  Feb-06             388                   48                 125
# 2  Mar-06             449                   50                 125
# 3  Apr-06             478                   57                 116
# 4  May-06             505                   56                 116
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost ($/t)  \
# 0                                         248            200
# 1                                         248            202
# 2                                         251            205
# 3                                         257            207
# 4                                         263            205
#
#    HRC - RM Spread ($/t)  CS Production (Mnt)  Exports (Mnt)  Imports (Mnt)  \
# 0                    187                 30.0            2.0            2.0
# 1                    185                 30.0            2.0            1.0
# 2                    244                 33.0            3.0            2.0
# 3                    271                 35.0            3.0            2.0
# 4                    300                 36.0            4.0            2.0
#
#    Net Exports (Mnt)  Export as % of Production  Cummulative FAI growth (%)  \
# 0                0.0                        7.0                        26.6
# 1                1.0                        7.0                        26.6
# 2                1.0                        9.0                        29.8
# 3                1.0                        9.0                        29.6
# 4                3.0                       12.0                        30.3
#
#    ACSU (Mnt)  Monthly Imports of semis & finished steel (Mt.)  \
# 0        30.0                                              NaN
# 1        29.0                                              NaN
# 2        32.0                                              NaN
# 3        33.0                                              NaN
# 4        33.0                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    YTD Growth rate of Investment (FAI)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    FAI in urban real estate development (y-o-y) Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Floor space under construction (y-o-y)  Automobile Production (y-o-y)  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
#
#    Civil Metal-Vessels/Steel Ships (y-o-y)  Household Fridges (y-o-y)  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
#
#    Air Conditioner (y-o-y)  Manufacturing PMI for steel
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN

# %%
df.to_csv('../data/processed/after_perc.csv', index=False)

# %% [markdown]
# ### Convert Month into Month and Year

# %%
# Convert 'Month' column to datetime format
df['Date'] = pd.to_datetime(df['Month'], format='%b-%y')

# Move column 'Date' to the front
df = df[['Date'] + [col for col in df.columns if col not in ['Date']]]
df.head()
# Out:
#         Date   Month  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0 2006-01-01  Jan-06             388                   47                 125
# 1 2006-02-01  Feb-06             388                   48                 125
# 2 2006-03-01  Mar-06             449                   50                 125
# 3 2006-04-01  Apr-06             478                   57                 116
# 4 2006-05-01  May-06             505                   56                 116
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost ($/t)  \
# 0                                         248            200
# 1                                         248            202
# 2                                         251            205
# 3                                         257            207
# 4                                         263            205
#
#    HRC - RM Spread ($/t)  CS Production (Mnt)  Exports (Mnt)  Imports (Mnt)  \
# 0                    187                 30.0            2.0            2.0
# 1                    185                 30.0            2.0            1.0
# 2                    244                 33.0            3.0            2.0
# 3                    271                 35.0            3.0            2.0
# 4                    300                 36.0            4.0            2.0
#
#    Net Exports (Mnt)  Export as % of Production  Cummulative FAI growth (%)  \
# 0                0.0                        7.0                        26.6
# 1                1.0                        7.0                        26.6
# 2                1.0                        9.0                        29.8
# 3                1.0                        9.0                        29.6
# 4                3.0                       12.0                        30.3
#
#    ACSU (Mnt)  Monthly Imports of semis & finished steel (Mt.)  \
# 0        30.0                                              NaN
# 1        29.0                                              NaN
# 2        32.0                                              NaN
# 3        33.0                                              NaN
# 4        33.0                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    YTD Growth rate of Investment (FAI)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    FAI in urban real estate development (y-o-y) Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Floor space under construction (y-o-y)  Automobile Production (y-o-y)  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
#
#    Civil Metal-Vessels/Steel Ships (y-o-y)  Household Fridges (y-o-y)  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
#
#    Air Conditioner (y-o-y)  Manufacturing PMI for steel
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN

# %% [markdown]
# ### Drop Columns - Correlation Analysis on Raw Data
# We exclude the month and date, and the dependent variable (the one to be predicted) in the correlation testing process.

# %%
corrdata = df.loc[:, df.columns.difference(['Date', 'Month', 'HRC (FOB, $/t)'])]
corr = corrdata.corr()

fig = plt.figure(figsize=(20, 10))
sns.heatmap(corr, mask=np.zeros_like(corr), annot=False, cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, fmt='.2f')
plt.yticks(ha='right', fontsize='x-small')
plt.xticks(rotation=45, ha='right', fontsize='x-small')
plt.show()

# %%
threshold = 0.8
high_corr_pairs = (
    corr.abs().where(np.triu(np.ones(corr.abs().shape), k=1).astype(bool))  # Keep only upper triangle
    .stack()  # Convert to Series
    .reset_index()
)

# Rename columns for clarity
high_corr_pairs.columns = ['Variable 1', 'Variable 2', 'Correlation']

# Filter pairs with correlation ≥ threshold
high_corr_pairs = pd.DataFrame(high_corr_pairs[high_corr_pairs['Correlation'] >= threshold])

# Compare the numbers of missing values in the correlated columns
missing_counts = df.isnull().sum()
high_corr_pairs['Missing Values (Var 1)'] = high_corr_pairs['Variable 1'].map(missing_counts)
high_corr_pairs['Missing Values (Var 2)'] = high_corr_pairs['Variable 2'].map(missing_counts)

# Display
high_corr_pairs
# Out:
#                                             Variable 1  \
# 2                                           ACSU (Mnt)
# 94                                 CS Production (Mnt)
# 138                         Cummulative FAI growth (%)
# 149         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 156         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 192                                      Exports (Mnt)
# 198  FAI in urban real estate development (y-o-y) G...
# 241                                 HCC (Aus FOB, $/t)
# 307     Monthly Export of semis & finished steel (Mt.)
#
#                                       Variable 2  Correlation  \
# 2                            CS Production (Mnt)     0.983331
# 94   Stocks of iron ore at China's seaport (Mt.)     0.819031
# 138          YTD Growth rate of Investment (FAI)     0.891828
# 149                          Iron Ore (CFR, $/t)     0.826307
# 156                                RM Cost ($/t)     0.839700
# 192                            Net Exports (Mnt)     0.977306
# 198       Floor space under construction (y-o-y)     0.902470
# 241                                RM Cost ($/t)     0.912347
# 307               Monthly Iron ore Imports (Mt.)     0.854674
#
#      Missing Values (Var 1)  Missing Values (Var 2)
# 2                         3                       1
# 94                        1                      15
# 138                       4                      23
# 149                       0                       0
# 156                       0                       0
# 192                       1                       1
# 198                      22                      79
# 241                       0                       0
# 307                      24                      33

# %% [markdown]
# #### Clarification
# After receving advice from the project sponsor and performing the regression analysis between the HRC Price in China and each factor, we chose to keeps the following factors for the next phase of the project.

# %%
# Reexamine the data columns
df.columns
# Out:
# Index(['Date', 'Month', 'HRC (FOB, $/t)', 'Iron Ore (CFR, $/t)',
#        'HCC (Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'RM Cost ($/t)', 'HRC - RM Spread ($/t)', 'CS Production (Mnt)',
#        'Exports (Mnt)', 'Imports (Mnt)', 'Net Exports (Mnt)',
#        'Export as % of Production', 'Cummulative FAI growth (%)', 'ACSU (Mnt)',
#        'Monthly Imports of semis & finished steel (Mt.)',
#        'Monthly Export of semis & finished steel (Mt.)',
#        'Monthly Iron ore Imports (Mt.)', 'YTD Iron ore Imports (Mt.)',
#        'YTD Iron ore Production (Mt.)', 'Monthly Iron ore Production (Mt.)',
#        'Stocks of iron ore at China's seaport (Mt.)',
#        'YTD Growth rate of Investment (FAI)',
#        'FAI in urban real estate development (y-o-y) Growth',
#        'Floor space under construction (y-o-y)',
#        'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
#        'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel'],
#       dtype='object')

# %%
df['Monthly Export of Semis & Finished Steel as % of Production'] = df['Monthly Export of semis & finished steel (Mt.)'] / df['CS Production (Mnt)'] * 100

df = df[['Date', 'HRC (FOB, $/t)', 'Iron Ore (CFR, $/t)', 'HCC (Aus FOB, $/t)',
         'Domestic Scrap (DDP Jiangsu incl. VAT $/t)', 'HRC - RM Spread ($/t)',
         'Monthly Export of Semis & Finished Steel as % of Production',
         'FAI in urban real estate development (y-o-y) Growth',
         'Automobile Production (y-o-y)', 'Civil Metal-Vessels/Steel Ships (y-o-y)',
         'Household Fridges (y-o-y)', 'Air Conditioner (y-o-y)']]

df.head(12)
# Out:
#          Date  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0  2006-01-01             388                   47                 125
# 1  2006-02-01             388                   48                 125
# 2  2006-03-01             449                   50                 125
# 3  2006-04-01             478                   57                 116
# 4  2006-05-01             505                   56                 116
# 5  2006-06-01             559                   55                 116
# 6  2006-07-01             540                   57                 116
# 7  2006-08-01             495                   60                 116
# 8  2006-09-01             472                   59                 116
# 9  2006-10-01             477                   62                  85
# 10 2006-11-01             470                   62                  84
# 11 2006-12-01             470                   61                  90
#
#     Domestic Scrap (DDP Jiangsu incl. VAT $/t)  HRC - RM Spread ($/t)  \
# 0                                          248                    187
# 1                                          248                    185
# 2                                          251                    244
# 3                                          257                    271
# 4                                          263                    300
# 5                                          266                    354
# 6                                          244                    332
# 7                                          253                    283
# 8                                          252                    261
# 9                                          260                    292
# 10                                         262                    288
# 11                                         270                    282
#
#     Monthly Export of Semis & Finished Steel as % of Production  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                           14.277778
# 9                                           13.657895
# 10                                          16.078947
# 11                                          15.512821
#
#     FAI in urban real estate development (y-o-y) Growth  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                24.3
# 9                                                24.1
# 10                                               24.0
# 11                                               21.8
#
#     Automobile Production (y-o-y)  Civil Metal-Vessels/Steel Ships (y-o-y)  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# 5                             NaN                                      NaN
# 6                             NaN                                      NaN
# 7                             NaN                                      NaN
# 8                            24.0                                      6.0
# 9                            25.1                                     11.4
# 10                           26.1                                      8.3
# 11                           27.0                                     13.1
#
#     Household Fridges (y-o-y)  Air Conditioner (y-o-y)
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                         NaN                      NaN
# 8                        34.2                      3.9
# 9                        31.8                      6.7
# 10                       28.9                      7.2
# 11                        NaN                      NaN

# %% [markdown]
# ### Total Number of Independent Variables (Factors to be Used for Prediction)

# %%
print(df.loc[:, df.columns.difference(['Date', 'HRC (FOB, $/t)'])].columns)
len(df.loc[:, df.columns.difference(['Date', 'HRC (FOB, $/t)'])].columns)
# Out:
# Index(['Air Conditioner (y-o-y)', 'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)',
#        'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'FAI in urban real estate development (y-o-y) Growth',
#        'HCC (Aus FOB, $/t)', 'HRC - RM Spread ($/t)',
#        'Household Fridges (y-o-y)', 'Iron Ore (CFR, $/t)',
#        'Monthly Export of Semis & Finished Steel as % of Production'],
#       dtype='object')
# 10

# %%
df.to_csv('../data/processed/after_drop_cols.csv', index=False)

# %% [markdown]
# ### Fill NaN Values with their Succeeding Values
# As the values before September 2006 for columns in Data 2 are not collected, the missing data is not random, hence we are not imputing them with the succeeding values as advised by the project owner.

# %%
mask = df['Date'] > '2006-08-01'

# For rows after 'Aug-06', fill missing values with the previous row's value
df.loc[mask] = df.loc[mask].fillna(method='bfill')
df.head(20)
# Out:
#          Date  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0  2006-01-01             388                   47                 125
# 1  2006-02-01             388                   48                 125
# 2  2006-03-01             449                   50                 125
# 3  2006-04-01             478                   57                 116
# 4  2006-05-01             505                   56                 116
# 5  2006-06-01             559                   55                 116
# 6  2006-07-01             540                   57                 116
# 7  2006-08-01             495                   60                 116
# 8  2006-09-01             472                   59                 116
# 9  2006-10-01             477                   62                  85
# 10 2006-11-01             470                   62                  84
# 11 2006-12-01             470                   61                  90
# 12 2007-01-01             470                   62                  98
# 13 2007-02-01             481                   62                 100
# 14 2007-03-01             560                   63                 103
# 15 2007-04-01             562                   70                 107
# 16 2007-05-01             591                   73                 109
# 17 2007-06-01             572                   68                 120
# 18 2007-07-01             526                   71                 129
# 19 2007-08-01             536                   75                 140
#
#     Domestic Scrap (DDP Jiangsu incl. VAT $/t)  HRC - RM Spread ($/t)  \
# 0                                          248                    187
# 1                                          248                    185
# 2                                          251                    244
# 3                                          257                    271
# 4                                          263                    300
# 5                                          266                    354
# 6                                          244                    332
# 7                                          253                    283
# 8                                          252                    261
# 9                                          260                    292
# 10                                         262                    288
# 11                                         270                    282
# 12                                         273                    273
# 13                                         288                    282
# 14                                         295                    357
# 15                                         303                    342
# 16                                         306                    365
# 17                                         314                    344
# 18                                         340                    284
# 19                                         349                    275
#
#     Monthly Export of Semis & Finished Steel as % of Production  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                           14.277778
# 9                                           13.657895
# 10                                          16.078947
# 11                                          15.512821
# 12                                          13.026316
# 13                                          13.666667
# 14                                          15.100000
# 15                                          19.585366
# 16                                          17.000000
# 17                                          16.511628
# 18                                          16.214286
# 19                                          13.619048
#
#     FAI in urban real estate development (y-o-y) Growth  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                24.3
# 9                                                24.1
# 10                                               24.0
# 11                                               21.8
# 12                                               24.3
# 13                                               24.3
# 14                                               26.9
# 15                                               27.4
# 16                                               27.5
# 17                                               28.5
# 18                                               28.9
# 19                                               29.0
#
#     Automobile Production (y-o-y)  Civil Metal-Vessels/Steel Ships (y-o-y)  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# 5                             NaN                                      NaN
# 6                             NaN                                      NaN
# 7                             NaN                                      NaN
# 8                            24.0                                      6.0
# 9                            25.1                                     11.4
# 10                           26.1                                      8.3
# 11                           27.0                                     13.1
# 12                           45.0                                      8.6
# 13                           21.5                                      8.6
# 14                           22.3                                      8.6
# 15                           21.4                                     23.0
# 16                           22.0                                     24.0
# 17                           22.9                                     20.8
# 18                           24.3                                     21.7
# 19                           24.0                                     27.8
#
#     Household Fridges (y-o-y)  Air Conditioner (y-o-y)
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                         NaN                      NaN
# 8                        34.2                      3.9
# 9                        31.8                      6.7
# 10                       28.9                      7.2
# 11                       15.8                     16.1
# 12                       15.8                     16.1
# 13                       15.8                     16.1
# 14                       15.8                     16.1
# 15                       15.8                     17.9
# 16                       15.8                     19.7
# 17                       15.8                     23.3
# 18                       15.8                     25.7
# 19                       15.8                     24.4

# %%
df.to_csv('../data/processed/after_fillna.csv')

# %% [markdown]
# ### Correlation Analysis on Processed Data

# %%
corrdata_rm_exports = df.loc[:, ['HRC (FOB, $/t)', 'Iron Ore (CFR, $/t)', 'HCC (Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
                     'Monthly Export of Semis & Finished Steel as % of Production']]
corr_rm_exports = corrdata_rm_exports.corr()

fig = plt.figure(figsize=(4, 4))
sns.heatmap(corr_rm_exports, mask=np.zeros_like(corr_rm_exports), annot=True, cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, fmt='.2f')
plt.yticks(ha='right', fontsize='small')
plt.xticks(rotation=45, ha='right', fontsize='small')
plt.show()

# %% [markdown]
# For model testing purpose, we drop all the rows with NaN values to avoid potential errors.

# %%
df_wo_na = df.dropna()
df_wo_na.to_csv('../data/final/wo_na.csv')
