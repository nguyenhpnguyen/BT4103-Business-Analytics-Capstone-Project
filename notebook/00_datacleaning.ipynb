# %% [markdown]
# # Data Cleaning
#
# * Data used: *"China HRC Price Model - Edited Combined Data.csv"*

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %%
## use this part, if you are using google colab
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## Data Loading

# %%
# Load the data and check the first few lines
dataset_path = "../data/raw/China HRC Price Model - Edited Combined Data.csv"
df = pd.read_csv(dataset_path)
df.head()
# Out:
#     Month  HRC \n(FOB, $/t)  Iron Ore \n(CFR, $/t)  HCC \n(Aus FOB, $/t)  \
# 0  Jan-25               388                     47                   125
# 1  Feb-25               388                     48                   125
# 2  Mar-25               449                     50                   125
# 3  Apr-25               478                     57                   116
# 4  May-25               505                     56                   116
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost \n($/t)  \
# 0                                         248              200
# 1                                         248              202
# 2                                         251              205
# 3                                         257              207
# 4                                         263              205
#
#    HRC - RM \nSpread ($/t)  CS Production (Mnt)  Exports \n(Mnt)  \
# 0                      187                 30.0              2.0
# 1                      185                 30.0              2.0
# 2                      244                 33.0              3.0
# 3                      271                 35.0              3.0
# 4                      300                 36.0              4.0
#
#    Imports \n(Mnt)  Net Exports (Mnt) Export as % of Production  \
# 0              2.0                0.0                        7%
# 1              1.0                1.0                        7%
# 2              2.0                1.0                        9%
# 3              2.0                1.0                        9%
# 4              2.0                3.0                       12%
#
#   Cummulative FAI growth (%)  ACSU \n(Mnt)  \
# 0                     26.60%          30.0
# 1                     26.60%          29.0
# 2                     29.80%          32.0
# 3                     29.60%          33.0
# 4                     30.30%          33.0
#
#    Monthly Imports of semis & finished steel (Mt.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   YTD Growth rate of  Investment  (Fixed asset investment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Fixed asset investment in real estate development in urban areas (y-o-y )Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Floor space under construction (y-o-y) Automobile Production (y-o-y)  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
#   Civil Metal-Vessels/Steel Ships (y-o-y) Household Fridges (y-o-y)  \
# 0                                     NaN                       NaN
# 1                                     NaN                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
#
#   Air Conditioner (y-o-y) Manufacturing PMI for steel
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN

# %%
df.columns
# Out:
# Index(['Month', 'HRC \n(FOB, $/t)', 'Iron Ore \n(CFR, $/t)',
#        'HCC \n(Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'RM Cost \n($/t)', 'HRC - RM \nSpread ($/t)', 'CS Production (Mnt)',
#        'Exports \n(Mnt)', 'Imports \n(Mnt)', 'Net Exports (Mnt)',
#        'Export as % of Production', 'Cummulative FAI growth (%)',
#        'ACSU \n(Mnt)', 'Monthly Imports of semis & finished steel (Mt.)',
#        'Monthly Export of semis & finished steel (Mt.)',
#        'Monthly Iron ore Imports (Mt.)', 'YTD Iron ore Imports (Mt.)',
#        'YTD Iron ore Production (Mt.)', 'Monthly Iron ore Production (Mt.)',
#        'Stocks of iron ore at China's seaport (Mt.)',
#        'YTD Growth rate of  Investment  (Fixed asset investment)',
#        'Fixed asset investment in real estate development in urban areas (y-o-y )Growth',
#        'Floor space under construction (y-o-y)',
#        'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
#        'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel'],
#       dtype='object')

# %%
df.rename(columns={'HRC \n(FOB, $/t)':'HRC (FOB, $/t)', 'Iron Ore \n(CFR, $/t)': 'Iron Ore (CFR, $/t)',
                   'HCC \n(Aus FOB, $/t)': 'HCC (Aus FOB, $/t)', 'RM Cost \n($/t)': 'RM Cost ($/t)',
                   'HRC - RM \nSpread ($/t)': 'HRC - RM Spread ($/t)', 'Exports \n(Mnt)': 'Exports (Mnt)',
                   'Imports \n(Mnt)': 'Imports (Mnt)', 'ACSU \n(Mnt)': 'ACSU (Mnt)',
                   'YTD Growth rate of  Investment  (Fixed asset investment)': 'YTD Growth rate of Investment (FAI)',
                   'Fixed asset investment in real estate development in urban areas (y-o-y )Growth':
                       'FAI in urban real estate development (y-o-y) Growth'},
          inplace=True)

# %%
df
# Out:
#       Month  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0    Jan-25             388                   47                 125
# 1    Feb-25             388                   48                 125
# 2    Mar-25             449                   50                 125
# 3    Apr-25             478                   57                 116
# 4    May-25             505                   56                 116
# ..      ...             ...                  ...                 ...
# 224  Sep-25             453                   94                 187
# 225  Oct-25             497                  104                 204
# 226  Nov-25             485                  102                 204
# 227  Dec-25             473                  104                 200
# 228  Jan-25             461                  102                 192
#
#      Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost ($/t)  \
# 0                                           248            200
# 1                                           248            202
# 2                                           251            205
# 3                                           257            207
# 4                                           263            205
# ..                                          ...            ...
# 224                                         337            337
# 225                                         354            370
# 226                                         353            368
# 227                                         356            366
# 228                                         337            355
#
#      HRC - RM Spread ($/t)  CS Production (Mnt)  Exports (Mnt)  Imports (Mnt)  \
# 0                      187                 30.0            2.0            2.0
# 1                      185                 30.0            2.0            1.0
# 2                      244                 33.0            3.0            2.0
# 3                      271                 35.0            3.0            2.0
# 4                      300                 36.0            4.0            2.0
# ..                     ...                  ...            ...            ...
# 224                    116                 77.0           10.0            1.0
# 225                    127                 82.0           11.0            1.0
# 226                    117                 78.0            9.0            0.0
# 227                    107                 76.0           10.0            1.0
# 228                    106                  NaN            NaN            NaN
#
#      Net Exports (Mnt) Export as % of Production Cummulative FAI growth (%)  \
# 0                  0.0                        7%                     26.60%
# 1                  1.0                        7%                     26.60%
# 2                  1.0                        9%                     29.80%
# 3                  1.0                        9%                     29.60%
# 4                  3.0                       12%                     30.30%
# ..                 ...                       ...                        ...
# 224               10.0                       13%                         3%
# 225               11.0                       14%                         3%
# 226                9.0                       12%                        NaN
# 227                9.0                       13%                        NaN
# 228                NaN                       NaN                        NaN
#
#      ACSU (Mnt)  Monthly Imports of semis & finished steel (Mt.)  \
# 0          30.0                                              NaN
# 1          29.0                                              NaN
# 2          32.0                                              NaN
# 3          33.0                                              NaN
# 4          33.0                                              NaN
# ..          ...                                              ...
# 224        66.0                                             0.55
# 225        70.0                                             0.54
# 226         NaN                                             0.47
# 227         NaN                                              NaN
# 228         NaN                                              NaN
#
#      Monthly Export of semis & finished steel (Mt.)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 224                                           10.15
# 225                                           11.18
# 226                                            9.28
# 227                                             NaN
# 228                                             NaN
#
#      Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# ..                              ...                         ...
# 224                          103.92                      918.87
# 225                          103.84                     1022.53
# 226                          101.86                         NaN
# 227                             NaN                         NaN
# 228                             NaN                         NaN
#
#      YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ..                             ...                                ...
# 224                          781.4                              84.88
# 225                          871.5                              90.16
# 226                            NaN                                NaN
# 227                            NaN                                NaN
# 228                            NaN                                NaN
#
#      Stocks of iron ore at China's seaport (Mt.)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 224                                       157.93
# 225                                       160.47
# 226                                       156.17
# 227                                          NaN
# 228                                          NaN
#
#     YTD Growth rate of Investment (FAI)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 224                               3.40%
# 225                               3.40%
# 226                                 NaN
# 227                                 NaN
# 228                                 NaN
#
#     FAI in urban real estate development (y-o-y) Growth  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                            -10.10%
# 225                                            -10.30%
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
#
#     Floor space under construction (y-o-y) Automobile Production (y-o-y)  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
# ..                                     ...                           ...
# 224                                -12.20%                         2.70%
# 225                                -12.40%                         3.00%
# 226                                    NaN                           NaN
# 227                                    NaN                           NaN
# 228                                    NaN                           NaN
#
#     Civil Metal-Vessels/Steel Ships (y-o-y) Household Fridges (y-o-y)  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
# ..                                      ...                       ...
# 224                                   1.10%                     7.50%
# 225                                   1.30%                     8.50%
# 226                                     NaN                       NaN
# 227                                     NaN                       NaN
# 228                                     NaN                       NaN
#
#     Air Conditioner (y-o-y) Manufacturing PMI for steel
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ..                      ...                         ...
# 224                   8.00%                          49
# 225                   8.20%                        54.6
# 226                     NaN                        50.6
# 227                     NaN                         NaN
# 228                     NaN                         NaN
#
# [229 rows x 29 columns]

# %% [markdown]
# ## Data Check
# * Missing data in columns.
# * Duplicates.
# * Data types.

# %%
df.isnull().sum()
# Out:
# Month                                                   0
# HRC (FOB, $/t)                                          0
# Iron Ore (CFR, $/t)                                     0
# HCC (Aus FOB, $/t)                                      0
# Domestic Scrap (DDP Jiangsu incl. VAT $/t)              0
# RM Cost ($/t)                                           0
# HRC - RM Spread ($/t)                                   0
# CS Production (Mnt)                                     1
# Exports (Mnt)                                           1
# Imports (Mnt)                                           1
# Net Exports (Mnt)                                       1
# Export as % of Production                               1
# Cummulative FAI growth (%)                              4
# ACSU (Mnt)                                              3
# Monthly Imports of semis & finished steel (Mt.)        20
# Monthly Export of semis & finished steel (Mt.)         24
# Monthly Iron ore Imports (Mt.)                         33
# YTD Iron ore Imports (Mt.)                             38
# YTD Iron ore Production (Mt.)                          32
# Monthly Iron ore Production (Mt.)                      45
# Stocks of iron ore at China's seaport (Mt.)            15
# YTD Growth rate of Investment (FAI)                    23
# FAI in urban real estate development (y-o-y) Growth    22
# Floor space under construction (y-o-y)                 79
# Automobile Production (y-o-y)                          19
# Civil Metal-Vessels/Steel Ships (y-o-y)                32
# Household Fridges (y-o-y)                              44
# Air Conditioner (y-o-y)                                34
# Manufacturing PMI for steel                            13
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Convert `str` to numeric
# As some column values are in string format with percentage sign (%), we delete the sign and convert them to float format.

# %%
# Check for columns with string values
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Month', 'Export as % of Production', 'Cummulative FAI growth (%)',
#        'YTD Growth rate of Investment (FAI)',
#        'FAI in urban real estate development (y-o-y) Growth',
#        'Floor space under construction (y-o-y)',
#        'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
#        'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel'],
#       dtype='object')

# %%
# Delete % sign from column values
col_w_perc = df.dtypes[df.dtypes == 'object'].index

for col in col_w_perc:
    if col == 'Month':
        continue
    df[col] = df[col].apply(lambda x: str(x).rstrip('%') if isinstance(x, str) else x)
    df[col] = pd.to_numeric(df[col])

df.head()
# Out:
#     Month  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0  Jan-25             388                   47                 125
# 1  Feb-25             388                   48                 125
# 2  Mar-25             449                   50                 125
# 3  Apr-25             478                   57                 116
# 4  May-25             505                   56                 116
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost ($/t)  \
# 0                                         248            200
# 1                                         248            202
# 2                                         251            205
# 3                                         257            207
# 4                                         263            205
#
#    HRC - RM Spread ($/t)  CS Production (Mnt)  Exports (Mnt)  Imports (Mnt)  \
# 0                    187                 30.0            2.0            2.0
# 1                    185                 30.0            2.0            1.0
# 2                    244                 33.0            3.0            2.0
# 3                    271                 35.0            3.0            2.0
# 4                    300                 36.0            4.0            2.0
#
#    Net Exports (Mnt)  Export as % of Production  Cummulative FAI growth (%)  \
# 0                0.0                        7.0                        26.6
# 1                1.0                        7.0                        26.6
# 2                1.0                        9.0                        29.8
# 3                1.0                        9.0                        29.6
# 4                3.0                       12.0                        30.3
#
#    ACSU (Mnt)  Monthly Imports of semis & finished steel (Mt.)  \
# 0        30.0                                              NaN
# 1        29.0                                              NaN
# 2        32.0                                              NaN
# 3        33.0                                              NaN
# 4        33.0                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    YTD Growth rate of Investment (FAI)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    FAI in urban real estate development (y-o-y) Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Floor space under construction (y-o-y)  Automobile Production (y-o-y)  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
#
#    Civil Metal-Vessels/Steel Ships (y-o-y)  Household Fridges (y-o-y)  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
#
#    Air Conditioner (y-o-y)  Manufacturing PMI for steel
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN

# %%
df.to_csv('../data/processed/after_perc.csv', index=False)

# %% [markdown]
# ### Convert Month into Month and Year

# %%
# Convert 'Month' column to datetime format
df['Date'] = pd.to_datetime(df['Month'], format='%b-%y')

# Move column 'Date' to the front
df = df[['Date'] + [col for col in df.columns if col not in ['Date']]]
df.head()
# Out:
#         Date   Month  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0 2025-01-01  Jan-25             388                   47                 125
# 1 2025-02-01  Feb-25             388                   48                 125
# 2 2025-03-01  Mar-25             449                   50                 125
# 3 2025-04-01  Apr-25             478                   57                 116
# 4 2025-05-01  May-25             505                   56                 116
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost ($/t)  \
# 0                                         248            200
# 1                                         248            202
# 2                                         251            205
# 3                                         257            207
# 4                                         263            205
#
#    HRC - RM Spread ($/t)  CS Production (Mnt)  Exports (Mnt)  Imports (Mnt)  \
# 0                    187                 30.0            2.0            2.0
# 1                    185                 30.0            2.0            1.0
# 2                    244                 33.0            3.0            2.0
# 3                    271                 35.0            3.0            2.0
# 4                    300                 36.0            4.0            2.0
#
#    Net Exports (Mnt)  Export as % of Production  Cummulative FAI growth (%)  \
# 0                0.0                        7.0                        26.6
# 1                1.0                        7.0                        26.6
# 2                1.0                        9.0                        29.8
# 3                1.0                        9.0                        29.6
# 4                3.0                       12.0                        30.3
#
#    ACSU (Mnt)  Monthly Imports of semis & finished steel (Mt.)  \
# 0        30.0                                              NaN
# 1        29.0                                              NaN
# 2        32.0                                              NaN
# 3        33.0                                              NaN
# 4        33.0                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    YTD Growth rate of Investment (FAI)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    FAI in urban real estate development (y-o-y) Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Floor space under construction (y-o-y)  Automobile Production (y-o-y)  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
#
#    Civil Metal-Vessels/Steel Ships (y-o-y)  Household Fridges (y-o-y)  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
#
#    Air Conditioner (y-o-y)  Manufacturing PMI for steel
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN

# %%
type(df['Month'][0])
# Out:
# str

# %% [markdown]
# ### Drop Columns - Correlation Analysis on Raw Data
# We exclude the month and date, and the dependent variable (the one to be predicted) in the correlation testing process.

# %%
corrdata = df.loc[:, df.columns.difference(['Date', 'Month', 'HRC (FOB, $/t)'])]
corr = corrdata.corr()

fig = plt.figure(figsize=(20, 10))
sns.heatmap(corr, mask=np.zeros_like(corr), annot=False, cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, fmt='.2f')
plt.yticks(ha='right', fontsize='x-small')
plt.xticks(rotation=45, ha='right', fontsize='x-small')
plt.show()

# %%
threshold = 0.8
high_corr_pairs = (
    corr.abs().where(np.triu(np.ones(corr.abs().shape), k=1).astype(bool))  # Keep only upper triangle
    .stack()  # Convert to Series
    .reset_index()
)

# Rename columns for clarity
high_corr_pairs.columns = ['Variable 1', 'Variable 2', 'Correlation']

# Filter pairs with correlation ≥ threshold
high_corr_pairs = pd.DataFrame(high_corr_pairs[high_corr_pairs['Correlation'] >= threshold])

# Compare the numbers of missing values in the correlated columns
missing_counts = df.isnull().sum()
high_corr_pairs['Missing Values (Var 1)'] = high_corr_pairs['Variable 1'].map(missing_counts)
high_corr_pairs['Missing Values (Var 2)'] = high_corr_pairs['Variable 2'].map(missing_counts)

# Display
high_corr_pairs
# Out:
#                                             Variable 1  \
# 2                                           ACSU (Mnt)
# 22                                          ACSU (Mnt)
# 94                                 CS Production (Mnt)
# 123                         Cummulative FAI growth (%)
# 138                         Cummulative FAI growth (%)
# 149         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 156         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 192                                      Exports (Mnt)
# 198  FAI in urban real estate development (y-o-y) G...
# 241                                 HCC (Aus FOB, $/t)
# 307     Monthly Export of semis & finished steel (Mt.)
#
#                                             Variable 2  Correlation  \
# 2                                  CS Production (Mnt)     0.983331
# 22         Stocks of iron ore at China's seaport (Mt.)     0.810243
# 94         Stocks of iron ore at China's seaport (Mt.)     0.829024
# 123  FAI in urban real estate development (y-o-y) G...     0.803096
# 138                YTD Growth rate of Investment (FAI)     0.993914
# 149                                Iron Ore (CFR, $/t)     0.826307
# 156                                      RM Cost ($/t)     0.839700
# 192                                  Net Exports (Mnt)     0.977306
# 198             Floor space under construction (y-o-y)     0.902470
# 241                                      RM Cost ($/t)     0.912347
# 307                     Monthly Iron ore Imports (Mt.)     0.854674
#
#      Missing Values (Var 1)  Missing Values (Var 2)
# 2                         3                       1
# 22                        3                      15
# 94                        1                      15
# 123                       4                      22
# 138                       4                      23
# 149                       0                       0
# 156                       0                       0
# 192                       1                       1
# 198                      22                      79
# 241                       0                       0
# 307                      24                      33

# %% [markdown]
# ### Fill NaN Values with their Succeeding Values
# As the values before September 2006 for columns in Data 2 are not collected, the missing data is not random, hence we are not imputing them with the succeeding values as advised by the project owner.

# %%
mask = df['Date'] > '2006-08-01'

# For rows after 'Aug-06', fill missing values with the previous row's value
df.loc[mask] = df.loc[mask].fillna(method='bfill')
df.head(20)
# Out:
#          Date   Month  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  \
# 0  2025-01-01  Jan-25             388                   47
# 1  2025-02-01  Feb-25             388                   48
# 2  2025-03-01  Mar-25             449                   50
# 3  2025-04-01  Apr-25             478                   57
# 4  2025-05-01  May-25             505                   56
# 5  2025-06-01  Jun-25             559                   55
# 6  2025-07-01  Jul-25             540                   57
# 7  2025-08-01  Aug-25             495                   60
# 8  2025-09-01  Sep-25             472                   59
# 9  2025-10-01  Oct-25             477                   62
# 10 2025-11-01  Nov-25             470                   62
# 11 2025-12-01  Dec-25             470                   61
# 12 2025-01-01  Jan-25             470                   62
# 13 2025-02-01  Feb-25             481                   62
# 14 2025-03-01  Mar-25             560                   63
# 15 2025-04-01  Apr-25             562                   70
# 16 2025-05-01  May-25             591                   73
# 17 2025-06-01  Jun-25             572                   68
# 18 2025-07-01  Jul-25             526                   71
# 19 2025-08-01  Aug-25             536                   75
#
#     HCC (Aus FOB, $/t)  Domestic Scrap (DDP Jiangsu incl. VAT $/t)  \
# 0                  125                                         248
# 1                  125                                         248
# 2                  125                                         251
# 3                  116                                         257
# 4                  116                                         263
# 5                  116                                         266
# 6                  116                                         244
# 7                  116                                         253
# 8                  116                                         252
# 9                   85                                         260
# 10                  84                                         262
# 11                  90                                         270
# 12                  98                                         273
# 13                 100                                         288
# 14                 103                                         295
# 15                 107                                         303
# 16                 109                                         306
# 17                 120                                         314
# 18                 129                                         340
# 19                 140                                         349
#
#     RM Cost ($/t)  HRC - RM Spread ($/t)  CS Production (Mnt)  Exports (Mnt)  \
# 0             200                    187                 30.0            2.0
# 1             202                    185                 30.0            2.0
# 2             205                    244                 33.0            3.0
# 3             207                    271                 35.0            3.0
# 4             205                    300                 36.0            4.0
# 5             205                    354                 37.0            5.0
# 6             208                    332                 36.0            4.0
# 7             212                    283                 37.0            5.0
# 8             211                    261                 36.0            5.0
# 9             185                    292                 38.0            5.0
# 10            182                    288                 38.0            6.0
# 11            188                    282                 39.0            6.0
# 12            197                    273                 38.0            5.0
# 13            199                    282                 36.0            5.0
# 14            203                    357                 40.0            6.0
# 15            219                    342                 41.0            8.0
# 16            226                    365                 42.0            7.0
# 17            228                    344                 43.0            7.0
# 18            242                    284                 42.0            7.0
# 19            260                    275                 42.0            6.0
#
#     Imports (Mnt)  Net Exports (Mnt)  Export as % of Production  \
# 0             2.0                0.0                        7.0
# 1             1.0                1.0                        7.0
# 2             2.0                1.0                        9.0
# 3             2.0                1.0                        9.0
# 4             2.0                3.0                       12.0
# 5             2.0                4.0                       15.0
# 6             2.0                3.0                       12.0
# 7             2.0                3.0                       14.0
# 8             2.0                3.0                       14.0
# 9             1.0                4.0                       14.0
# 10            2.0                5.0                       16.0
# 11            2.0                4.0                       15.0
# 12            2.0                3.0                       13.0
# 13            1.0                4.0                       13.0
# 14            2.0                4.0                       15.0
# 15            2.0                6.0                       20.0
# 16            1.0                6.0                       17.0
# 17            1.0                6.0                       17.0
# 18            1.0                5.0                       16.0
# 19            1.0                4.0                       14.0
#
#     Cummulative FAI growth (%)  ACSU (Mnt)  \
# 0                         26.6        30.0
# 1                         26.6        29.0
# 2                         29.8        32.0
# 3                         29.6        33.0
# 4                         30.3        33.0
# 5                         31.3        33.0
# 6                         30.5        33.0
# 7                         29.1        33.0
# 8                         28.2        33.0
# 9                         26.8        34.0
# 10                        26.6        31.0
# 11                        24.5        32.0
# 12                        23.4        35.0
# 13                        23.4        32.0
# 14                        25.3        36.0
# 15                        25.5        34.0
# 16                        25.9        35.0
# 17                        26.7        36.0
# 18                        26.6        36.0
# 19                        26.7        37.0
#
#     Monthly Imports of semis & finished steel (Mt.)  \
# 0                                              1.61
# 1                                              1.61
# 2                                              1.61
# 3                                              1.61
# 4                                              1.61
# 5                                              1.61
# 6                                              1.61
# 7                                              1.61
# 8                                              1.61
# 9                                              1.42
# 10                                             1.45
# 11                                             1.53
# 12                                             1.53
# 13                                             1.28
# 14                                             1.61
# 15                                             1.66
# 16                                             1.41
# 17                                             1.44
# 18                                             1.42
# 19                                             1.49
#
#     Monthly Export of semis & finished steel (Mt.)  \
# 0                                             5.14
# 1                                             5.14
# 2                                             5.14
# 3                                             5.14
# 4                                             5.14
# 5                                             5.14
# 6                                             5.14
# 7                                             5.14
# 8                                             5.14
# 9                                             5.19
# 10                                            6.11
# 11                                            6.05
# 12                                            4.95
# 13                                            4.92
# 14                                            6.04
# 15                                            8.03
# 16                                            7.14
# 17                                            7.10
# 18                                            6.81
# 19                                            5.72
#
#     Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                            28.14                      247.20
# 1                            28.14                      247.20
# 2                            28.14                      247.20
# 3                            28.14                      247.20
# 4                            28.14                      247.20
# 5                            28.14                      247.20
# 6                            28.14                      247.20
# 7                            28.14                      247.20
# 8                            28.14                      247.20
# 9                            21.97                      297.69
# 10                           28.56                      297.69
# 11                           35.85                      326.30
# 12                           35.85                      133.55
# 13                           28.75                      133.55
# 14                           35.62                      133.55
# 15                           33.37                      133.55
# 16                           27.62                      161.17
# 17                           26.90                      187.92
# 18                           33.61                      221.52
# 19                           29.29                      250.81
#
#     YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                          405.80                              56.50
# 1                          405.80                              56.50
# 2                          405.80                              56.50
# 3                          405.80                              56.50
# 4                          405.80                              56.50
# 5                          405.80                              56.50
# 6                          405.80                              56.50
# 7                          405.80                              56.50
# 8                          405.80                              56.50
# 9                          462.30                              56.50
# 10                         521.50                              59.20
# 11                         588.20                              66.70
# 12                         252.28                              69.01
# 13                         252.28                              69.01
# 14                         252.28                              69.01
# 15                         252.28                              69.01
# 16                         252.28                              69.01
# 17                         321.29                              69.01
# 18                         380.42                              59.13
# 19                         442.17                              61.75
#
#     Stocks of iron ore at China's seaport (Mt.)  \
# 0                                         41.00
# 1                                         41.00
# 2                                         41.00
# 3                                         41.00
# 4                                         41.00
# 5                                         41.00
# 6                                         41.00
# 7                                         41.00
# 8                                         41.00
# 9                                         40.77
# 10                                        37.48
# 11                                        38.20
# 12                                        39.80
# 13                                        44.60
# 14                                        44.50
# 15                                        43.07
# 16                                        45.06
# 17                                        44.29
# 18                                        44.43
# 19                                        39.91
#
#     YTD Growth rate of Investment (FAI)  \
# 0                                  27.3
# 1                                  27.3
# 2                                  27.3
# 3                                  27.3
# 4                                  27.3
# 5                                  27.3
# 6                                  27.3
# 7                                  27.3
# 8                                  27.3
# 9                                  26.8
# 10                                 26.6
# 11                                 24.0
# 12                                 23.4
# 13                                 23.4
# 14                                 23.7
# 15                                 25.5
# 16                                 25.9
# 17                                 25.9
# 18                                 26.6
# 19                                 26.7
#
#     FAI in urban real estate development (y-o-y) Growth  \
# 0                                                24.3
# 1                                                24.3
# 2                                                24.3
# 3                                                24.3
# 4                                                24.3
# 5                                                24.3
# 6                                                24.3
# 7                                                24.3
# 8                                                24.3
# 9                                                24.1
# 10                                               24.0
# 11                                               21.8
# 12                                               24.3
# 13                                               24.3
# 14                                               26.9
# 15                                               27.4
# 16                                               27.5
# 17                                               28.5
# 18                                               28.9
# 19                                               29.0
#
#     Floor space under construction (y-o-y)  Automobile Production (y-o-y)  \
# 0                                     18.5                           24.0
# 1                                     18.5                           24.0
# 2                                     18.5                           24.0
# 3                                     18.5                           24.0
# 4                                     18.5                           24.0
# 5                                     18.5                           24.0
# 6                                     18.5                           24.0
# 7                                     18.5                           24.0
# 8                                     18.5                           24.0
# 9                                     18.8                           25.1
# 10                                    18.4                           26.1
# 11                                    17.2                           27.0
# 12                                    17.2                           45.0
# 13                                    17.2                           21.5
# 14                                    19.3                           22.3
# 15                                    21.3                           21.4
# 16                                    20.6                           22.0
# 17                                    20.6                           22.9
# 18                                    21.5                           24.3
# 19                                    21.6                           24.0
#
#     Civil Metal-Vessels/Steel Ships (y-o-y)  Household Fridges (y-o-y)  \
# 0                                       6.0                       34.2
# 1                                       6.0                       34.2
# 2                                       6.0                       34.2
# 3                                       6.0                       34.2
# 4                                       6.0                       34.2
# 5                                       6.0                       34.2
# 6                                       6.0                       34.2
# 7                                       6.0                       34.2
# 8                                       6.0                       34.2
# 9                                      11.4                       31.8
# 10                                      8.3                       28.9
# 11                                     13.1                       15.8
# 12                                      8.6                       15.8
# 13                                      8.6                       15.8
# 14                                      8.6                       15.8
# 15                                     23.0                       15.8
# 16                                     24.0                       15.8
# 17                                     20.8                       15.8
# 18                                     21.7                       15.8
# 19                                     27.8                       15.8
#
#     Air Conditioner (y-o-y)  Manufacturing PMI for steel
# 0                       3.9                         51.7
# 1                       3.9                         51.7
# 2                       3.9                         51.7
# 3                       3.9                         51.7
# 4                       3.9                         51.7
# 5                       3.9                         51.7
# 6                       3.9                         51.7
# 7                       3.9                         51.7
# 8                       3.9                         51.7
# 9                       6.7                         55.9
# 10                      7.2                         54.9
# 11                     16.1                         50.1
# 12                     16.1                         55.4
# 13                     16.1                         60.3
# 14                     16.1                         54.2
# 15                     17.9                         55.8
# 16                     19.7                         60.1
# 17                     23.3                         54.4
# 18                     25.7                         54.7
# 19                     24.4                         55.9

# %%
df.to_csv('../data/processed/after_fillna.csv')

# %% [markdown]
# For model testing purpose, we drop all the rows with NaN values to avoid potential errors.

# %%
df_wo_na = df.dropna()
df_wo_na.to_csv('../data/final/wo_na_all_cols.csv')

# %% [markdown]
# ### Total Number of Independent Variables (Factors to be Used for Prediction)

# %% [markdown]
# #### Clarification
# After receving advice from the project sponsor and performing the regression analysis between the HRC Price in China and each factor, we chose to keeps the following factors for the next phase of the project.

# %%
# Reexamine the data columns
df.columns
# Out:
# Index(['Date', 'Month', 'HRC (FOB, $/t)', 'Iron Ore (CFR, $/t)',
#        'HCC (Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'RM Cost ($/t)', 'HRC - RM Spread ($/t)', 'CS Production (Mnt)',
#        'Exports (Mnt)', 'Imports (Mnt)', 'Net Exports (Mnt)',
#        'Export as % of Production', 'Cummulative FAI growth (%)', 'ACSU (Mnt)',
#        'Monthly Imports of semis & finished steel (Mt.)',
#        'Monthly Export of semis & finished steel (Mt.)',
#        'Monthly Iron ore Imports (Mt.)', 'YTD Iron ore Imports (Mt.)',
#        'YTD Iron ore Production (Mt.)', 'Monthly Iron ore Production (Mt.)',
#        'Stocks of iron ore at China's seaport (Mt.)',
#        'YTD Growth rate of Investment (FAI)',
#        'FAI in urban real estate development (y-o-y) Growth',
#        'Floor space under construction (y-o-y)',
#        'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
#        'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel'],
#       dtype='object')

# %%
df['Monthly Export of Semis & Finished Steel as % of Production'] = df['Monthly Export of semis & finished steel (Mt.)'] / df['CS Production (Mnt)'] * 100

df = df[['Date', 'HRC (FOB, $/t)', 'Iron Ore (CFR, $/t)', 'HCC (Aus FOB, $/t)',
         'Domestic Scrap (DDP Jiangsu incl. VAT $/t)', 'HRC - RM Spread ($/t)',
         'Monthly Export of Semis & Finished Steel as % of Production',
         'FAI in urban real estate development (y-o-y) Growth',
         'Automobile Production (y-o-y)', 'Civil Metal-Vessels/Steel Ships (y-o-y)',
         'Household Fridges (y-o-y)', 'Air Conditioner (y-o-y)']]

df.head(12)
# Out:
#          Date  HRC (FOB, $/t)  Iron Ore (CFR, $/t)  HCC (Aus FOB, $/t)  \
# 0  2025-01-01             388                   47                 125
# 1  2025-02-01             388                   48                 125
# 2  2025-03-01             449                   50                 125
# 3  2025-04-01             478                   57                 116
# 4  2025-05-01             505                   56                 116
# 5  2025-06-01             559                   55                 116
# 6  2025-07-01             540                   57                 116
# 7  2025-08-01             495                   60                 116
# 8  2025-09-01             472                   59                 116
# 9  2025-10-01             477                   62                  85
# 10 2025-11-01             470                   62                  84
# 11 2025-12-01             470                   61                  90
#
#     Domestic Scrap (DDP Jiangsu incl. VAT $/t)  HRC - RM Spread ($/t)  \
# 0                                          248                    187
# 1                                          248                    185
# 2                                          251                    244
# 3                                          257                    271
# 4                                          263                    300
# 5                                          266                    354
# 6                                          244                    332
# 7                                          253                    283
# 8                                          252                    261
# 9                                          260                    292
# 10                                         262                    288
# 11                                         270                    282
#
#     Monthly Export of Semis & Finished Steel as % of Production  \
# 0                                           17.133333
# 1                                           17.133333
# 2                                           15.575758
# 3                                           14.685714
# 4                                           14.277778
# 5                                           13.891892
# 6                                           14.277778
# 7                                           13.891892
# 8                                           14.277778
# 9                                           13.657895
# 10                                          16.078947
# 11                                          15.512821
#
#     FAI in urban real estate development (y-o-y) Growth  \
# 0                                                24.3
# 1                                                24.3
# 2                                                24.3
# 3                                                24.3
# 4                                                24.3
# 5                                                24.3
# 6                                                24.3
# 7                                                24.3
# 8                                                24.3
# 9                                                24.1
# 10                                               24.0
# 11                                               21.8
#
#     Automobile Production (y-o-y)  Civil Metal-Vessels/Steel Ships (y-o-y)  \
# 0                            24.0                                      6.0
# 1                            24.0                                      6.0
# 2                            24.0                                      6.0
# 3                            24.0                                      6.0
# 4                            24.0                                      6.0
# 5                            24.0                                      6.0
# 6                            24.0                                      6.0
# 7                            24.0                                      6.0
# 8                            24.0                                      6.0
# 9                            25.1                                     11.4
# 10                           26.1                                      8.3
# 11                           27.0                                     13.1
#
#     Household Fridges (y-o-y)  Air Conditioner (y-o-y)
# 0                        34.2                      3.9
# 1                        34.2                      3.9
# 2                        34.2                      3.9
# 3                        34.2                      3.9
# 4                        34.2                      3.9
# 5                        34.2                      3.9
# 6                        34.2                      3.9
# 7                        34.2                      3.9
# 8                        34.2                      3.9
# 9                        31.8                      6.7
# 10                       28.9                      7.2
# 11                       15.8                     16.1

# %%
print(df.loc[:, df.columns.difference(['Date', 'HRC (FOB, $/t)'])].columns)
len(df.loc[:, df.columns.difference(['Date', 'HRC (FOB, $/t)'])].columns)
# Out:
# Index(['Air Conditioner (y-o-y)', 'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)',
#        'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'FAI in urban real estate development (y-o-y) Growth',
#        'HCC (Aus FOB, $/t)', 'HRC - RM Spread ($/t)',
#        'Household Fridges (y-o-y)', 'Iron Ore (CFR, $/t)',
#        'Monthly Export of Semis & Finished Steel as % of Production'],
#       dtype='object')
# 10

# %%
df.to_csv('../data/final/wo_na.csv', index=False)

# %% [markdown]
# ### Correlation Analysis on Processed Data

# %%
corrdata_rm_exports = df.loc[:, ['HRC (FOB, $/t)', 'Iron Ore (CFR, $/t)', 'HCC (Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
                     'Monthly Export of Semis & Finished Steel as % of Production']]
corr_rm_exports = corrdata_rm_exports.corr()

fig = plt.figure(figsize=(4, 4))
sns.heatmap(corr_rm_exports, mask=np.zeros_like(corr_rm_exports), annot=True, cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, fmt='.2f')
plt.yticks(ha='right', fontsize='small')
plt.xticks(rotation=45, ha='right', fontsize='small')
plt.show()
