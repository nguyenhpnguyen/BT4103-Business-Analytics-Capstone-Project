# %% [markdown]
# # Data Cleaning
#
# * Data used: *"China HRC Price Model - Edited Combined Data.csv"*

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %%
## use this part, if you are using google colab
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## Data Loading

# %%
# Load the data and check the first few lines
dataset_path = "../data/raw/China HRC Price Model - Edited Combined Data.csv"
df = pd.read_csv(dataset_path) 
df.head()
# Out:
#     Month  HRC \r\n(FOB, $/t)  Iron Ore \r\n(CFR, $/t)  \
# 0  Jan-06                 388                       47
# 1  Feb-06                 388                       48
# 2  Mar-06                 449                       50
# 3  Apr-06                 478                       57
# 4  May-06                 505                       56
#
#    HCC \r\n(Aus FOB, $/t)  Domestic Scrap (DDP Jiangsu incl. VAT $/t)  \
# 0                     125                                         248
# 1                     125                                         248
# 2                     125                                         251
# 3                     116                                         257
# 4                     116                                         263
#
#    RM Cost \r\n($/t)  HRC - RM \r\nSpread ($/t)  CS Production (Mnt)  \
# 0                200                        187                 30.0
# 1                202                        185                 30.0
# 2                205                        244                 33.0
# 3                207                        271                 35.0
# 4                205                        300                 36.0
#
#    Exports \r\n(Mnt)  Imports \r\n(Mnt)  Net Exports (Mnt)  \
# 0                2.0                2.0                0.0
# 1                2.0                1.0                1.0
# 2                3.0                2.0                1.0
# 3                3.0                2.0                1.0
# 4                4.0                2.0                3.0
#
#   Export as % of Production Cummulative FAI growth (%)  \
# 0                        7%                      26.6%
# 1                        7%                      26.6%
# 2                        9%                      29.8%
# 3                        9%                      29.6%
# 4                       12%                      30.3%
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t).1  ACSU \r\n(Mnt)  \
# 0                                           248            30.0
# 1                                           248            29.0
# 2                                           251            32.0
# 3                                           257            33.0
# 4                                           263            33.0
#
#    Monthly Imports of semis & finished steel (Mt.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   YTD Growth rate of  Investment  (Fixed asset investment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Fixed asset investment in real estate development in urban areas (y-o-y )Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Floor space under construction (y-o-y) Automobile Production (y-o-y)  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
#   Civil Metal-Vessels/Steel Ships (y-o-y) Household Fridges (y-o-y)  \
# 0                                     NaN                       NaN
# 1                                     NaN                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
#
#   Air Conditioner (y-o-y) Manufacturing PMI for steel
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN

# %%
df.columns
# Out:
# Index(['Month', 'HRC \r\n(FOB, $/t)', 'Iron Ore \r\n(CFR, $/t)',
#        'HCC \r\n(Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'RM Cost \r\n($/t)', 'HRC - RM \r\nSpread ($/t)', 'CS Production (Mnt)',
#        'Exports \r\n(Mnt)', 'Imports \r\n(Mnt)', 'Net Exports (Mnt)',
#        'Export as % of Production', 'Cummulative FAI growth (%)',
#        'Domestic Scrap (DDP Jiangsu incl. VAT $/t).1', 'ACSU \r\n(Mnt)',
#        'Monthly Imports of semis & finished steel (Mt.)',
#        'Monthly Export of semis & finished steel (Mt.)',
#        'Monthly Iron ore Imports (Mt.)', 'YTD Iron ore Imports (Mt.)',
#        'YTD Iron ore Production (Mt.)', 'Monthly Iron ore Production (Mt.)',
#        'Stocks of iron ore at China's seaport (Mt.)',
#        'YTD Growth rate of  Investment  (Fixed asset investment)',
#        'Fixed asset investment in real estate development in urban areas (y-o-y )Growth',
#        'Floor space under construction (y-o-y)',
#        'Automobile Production (y-o-y)',
#        'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
#        'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel'],
#       dtype='object')

# %% [markdown]
# ## Data Check
# * Missing data in columns.
# * Duplicates.
# * Data types.

# %%
df.isnull().sum()
# Out:
# Month                                                                               0
# HRC \r\n(FOB, $/t)                                                                  0
# Iron Ore \r\n(CFR, $/t)                                                             0
# HCC \r\n(Aus FOB, $/t)                                                              0
# Domestic Scrap (DDP Jiangsu incl. VAT $/t)                                          0
# RM Cost \r\n($/t)                                                                   0
# HRC - RM \r\nSpread ($/t)                                                           0
# CS Production (Mnt)                                                                 1
# Exports \r\n(Mnt)                                                                   1
# Imports \r\n(Mnt)                                                                   1
# Net Exports (Mnt)                                                                   1
# Export as % of Production                                                           1
# Cummulative FAI growth (%)                                                          4
# Domestic Scrap (DDP Jiangsu incl. VAT $/t).1                                        0
# ACSU \r\n(Mnt)                                                                      3
# Monthly Imports of semis & finished steel (Mt.)                                    20
# Monthly Export of semis & finished steel (Mt.)                                     24
# Monthly Iron ore Imports (Mt.)                                                     33
# YTD Iron ore Imports (Mt.)                                                         38
# YTD Iron ore Production (Mt.)                                                      32
# Monthly Iron ore Production (Mt.)                                                  45
# Stocks of iron ore at China's seaport (Mt.)                                        15
# YTD Growth rate of  Investment  (Fixed asset investment)                           23
# Fixed asset investment in real estate development in urban areas (y-o-y )Growth    22
# Floor space under construction (y-o-y)                                             79
# Automobile Production (y-o-y)                                                      19
# Civil Metal-Vessels/Steel Ships (y-o-y)                                            32
# Household Fridges (y-o-y)                                                          44
# Air Conditioner (y-o-y)                                                            34
# Manufacturing PMI for steel                                                        13
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Convert `str` to numeric
# As some column values are in string format with percentage sign (%), we delete the sign and convert them to float format.

# %%
type(df['Export as % of Production'][0])
# Out:
# str

# %%
# Delete % sign from column values
col_w_perc = ['Export as % of Production', 'Cummulative FAI growth (%)',
              'YTD Growth rate of  Investment  (Fixed asset investment)',
              'Fixed asset investment in real estate development in urban areas (y-o-y )Growth',
              'Floor space under construction (y-o-y)', 'Automobile Production (y-o-y)',
              'Civil Metal-Vessels/Steel Ships (y-o-y)', 'Household Fridges (y-o-y)',
              'Air Conditioner (y-o-y)', 'Manufacturing PMI for steel']

for col in col_w_perc:
    df[col] = df[col].apply(lambda x: str(x).rstrip('%') if isinstance(x, str) else x)
    df[col] = pd.to_numeric(df[col])

df.head()
# Out:
#     Month  HRC \r\n(FOB, $/t)  Iron Ore \r\n(CFR, $/t)  \
# 0  Jan-06                 388                       47
# 1  Feb-06                 388                       48
# 2  Mar-06                 449                       50
# 3  Apr-06                 478                       57
# 4  May-06                 505                       56
#
#    HCC \r\n(Aus FOB, $/t)  Domestic Scrap (DDP Jiangsu incl. VAT $/t)  \
# 0                     125                                         248
# 1                     125                                         248
# 2                     125                                         251
# 3                     116                                         257
# 4                     116                                         263
#
#    RM Cost \r\n($/t)  HRC - RM \r\nSpread ($/t)  CS Production (Mnt)  \
# 0                200                        187                 30.0
# 1                202                        185                 30.0
# 2                205                        244                 33.0
# 3                207                        271                 35.0
# 4                205                        300                 36.0
#
#    Exports \r\n(Mnt)  Imports \r\n(Mnt)  Net Exports (Mnt)  \
# 0                2.0                2.0                0.0
# 1                2.0                1.0                1.0
# 2                3.0                2.0                1.0
# 3                3.0                2.0                1.0
# 4                4.0                2.0                3.0
#
#    Export as % of Production  Cummulative FAI growth (%)  \
# 0                        7.0                        26.6
# 1                        7.0                        26.6
# 2                        9.0                        29.8
# 3                        9.0                        29.6
# 4                       12.0                        30.3
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t).1  ACSU \r\n(Mnt)  \
# 0                                           248            30.0
# 1                                           248            29.0
# 2                                           251            32.0
# 3                                           257            33.0
# 4                                           263            33.0
#
#    Monthly Imports of semis & finished steel (Mt.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    YTD Growth rate of  Investment  (Fixed asset investment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fixed asset investment in real estate development in urban areas (y-o-y )Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Floor space under construction (y-o-y)  Automobile Production (y-o-y)  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
#
#    Civil Metal-Vessels/Steel Ships (y-o-y)  Household Fridges (y-o-y)  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
#
#    Air Conditioner (y-o-y)  Manufacturing PMI for steel
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN

# %%
df.to_csv('../data/processed/after_perc.csv', index=False)

# %% [markdown]
# ### Convert Month into Month and Year

# %%
# Separate 'Month' into 'Month' and 'Year'
df['Month_Dt'] = pd.to_datetime(df['Month'], format='%b-%y')

# Extract the numeric month and year
df['Month'] = df['Month_Dt'].dt.month
df['Year'] = df['Month_Dt'].dt.year

df = df[['Month_Dt', 'Month', 'Year'] + [col for col in df.columns if col not in ['Month_Dt', 'Month', 'Year']]]
df.head()
# Out:
#     Month_Dt  Month  Year  HRC \r\n(FOB, $/t)  Iron Ore \r\n(CFR, $/t)  \
# 0 2006-01-01      1  2006                 388                       47
# 1 2006-02-01      2  2006                 388                       48
# 2 2006-03-01      3  2006                 449                       50
# 3 2006-04-01      4  2006                 478                       57
# 4 2006-05-01      5  2006                 505                       56
#
#    HCC \r\n(Aus FOB, $/t)  Domestic Scrap (DDP Jiangsu incl. VAT $/t)  \
# 0                     125                                         248
# 1                     125                                         248
# 2                     125                                         251
# 3                     116                                         257
# 4                     116                                         263
#
#    RM Cost \r\n($/t)  HRC - RM \r\nSpread ($/t)  CS Production (Mnt)  \
# 0                200                        187                 30.0
# 1                202                        185                 30.0
# 2                205                        244                 33.0
# 3                207                        271                 35.0
# 4                205                        300                 36.0
#
#    Exports \r\n(Mnt)  Imports \r\n(Mnt)  Net Exports (Mnt)  \
# 0                2.0                2.0                0.0
# 1                2.0                1.0                1.0
# 2                3.0                2.0                1.0
# 3                3.0                2.0                1.0
# 4                4.0                2.0                3.0
#
#    Export as % of Production  Cummulative FAI growth (%)  \
# 0                        7.0                        26.6
# 1                        7.0                        26.6
# 2                        9.0                        29.8
# 3                        9.0                        29.6
# 4                       12.0                        30.3
#
#    Domestic Scrap (DDP Jiangsu incl. VAT $/t).1  ACSU \r\n(Mnt)  \
# 0                                           248            30.0
# 1                                           248            29.0
# 2                                           251            32.0
# 3                                           257            33.0
# 4                                           263            33.0
#
#    Monthly Imports of semis & finished steel (Mt.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Monthly Export of semis & finished steel (Mt.)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Monthly Iron ore Imports (Mt.)  YTD Iron ore Imports (Mt.)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    YTD Iron ore Production (Mt.)  Monthly Iron ore Production (Mt.)  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Stocks of iron ore at China's seaport (Mt.)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    YTD Growth rate of  Investment  (Fixed asset investment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fixed asset investment in real estate development in urban areas (y-o-y )Growth  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Floor space under construction (y-o-y)  Automobile Production (y-o-y)  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
#
#    Civil Metal-Vessels/Steel Ships (y-o-y)  Household Fridges (y-o-y)  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
#
#    Air Conditioner (y-o-y)  Manufacturing PMI for steel
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN

# %% [markdown]
# ### Drop Columns with High Correlation Coefficients (>0.8)
# We exclude the month and year, and the dependent variable (the one to be predicted) in the correlation testing process.

# %%
corrdata = df.loc[:, df.columns.difference(['Month_Dt', 'Month', 'Year', 'HRC \n(FOB, $/t)'])]
corr = corrdata.corr()
sns.heatmap(corr, mask=np.zeros_like(corr), annot=False, cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, fmt='.2f' ,  )
# Out:
# <Axes: >

# %% [markdown]
# We note that there are some variables with high collinearity, hence considering dropping some of them to reduce the computation cost when running the models.
# * Firstly, we check for variable pairs with correlation coefficients higher than 0.8.
# * As it is advised to keep either `RM Cost ($/t)` or the combination of `Iron Ore (CFR, $/t)` and `HCC (Aus FOB, $/t)`, we choose to keep `RM Cost ($/t)`.
# * Next, between a highly correlated pair, we drop the variable with more NaN values.
# * Finally, for highly correlated pairs with the same number of NaN values, we compare the variables' range and drop the one with larger range.
#     * `Domestic Scrap (DDP Jiangsu incl. VAT $/t)` vs. `RM Cost ($/t)` (corr_coef=0.839700): `RM Cost ($/t)` is dropped.
#     * `Exports (Mnt)` vs. `Net Exports (Mnt)` (corr_coef=0.977306): `Net Exports (Mnt)` is dropped.

# %%
threshold = 0.8
high_corr_pairs = (
    corr.abs().where(np.triu(np.ones(corr.abs().shape), k=1).astype(bool))  # Keep only upper triangle
    .stack()  # Convert to Series
    .reset_index()
)

# Rename columns for clarity
high_corr_pairs.columns = ['Variable 1', 'Variable 2', 'Correlation']

# Filter pairs with correlation ≥ threshold
high_corr_pairs = pd.DataFrame(high_corr_pairs[high_corr_pairs['Correlation'] >= threshold])

# Compare the numbers of missing values in the correlated columns
missing_counts = df.isnull().sum()
high_corr_pairs['Missing Values (Var 1)'] = high_corr_pairs['Variable 1'].map(missing_counts)
high_corr_pairs['Missing Values (Var 2)'] = high_corr_pairs['Variable 2'].map(missing_counts)

# Display
high_corr_pairs.to_csv('../data/processed/highly_corr_vars.csv', index=False)
high_corr_pairs
# Out:
#                                             Variable 1  \
# 2                                       ACSU \r\n(Mnt)
# 102                                CS Production (Mnt)
# 150                         Cummulative FAI growth (%)
# 153         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 159         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 163         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 170         Domestic Scrap (DDP Jiangsu incl. VAT $/t)
# 180       Domestic Scrap (DDP Jiangsu incl. VAT $/t).1
# 184       Domestic Scrap (DDP Jiangsu incl. VAT $/t).1
# 191       Domestic Scrap (DDP Jiangsu incl. VAT $/t).1
# 229                                  Exports \r\n(Mnt)
# 235  Fixed asset investment in real estate developm...
# 281                             HCC \r\n(Aus FOB, $/t)
# 362     Monthly Export of semis & finished steel (Mt.)
#
#                                             Variable 2  Correlation  \
# 2                                  CS Production (Mnt)     0.983331
# 102        Stocks of iron ore at China's seaport (Mt.)     0.819031
# 150  YTD Growth rate of  Investment  (Fixed asset i...     0.891828
# 153       Domestic Scrap (DDP Jiangsu incl. VAT $/t).1     1.000000
# 159                                 HRC \r\n(FOB, $/t)     0.840440
# 163                            Iron Ore \r\n(CFR, $/t)     0.826307
# 170                                  RM Cost \r\n($/t)     0.839700
# 180                                 HRC \r\n(FOB, $/t)     0.840440
# 184                            Iron Ore \r\n(CFR, $/t)     0.826307
# 191                                  RM Cost \r\n($/t)     0.839700
# 229                                  Net Exports (Mnt)     0.977306
# 235             Floor space under construction (y-o-y)     0.902470
# 281                                  RM Cost \r\n($/t)     0.912347
# 362                     Monthly Iron ore Imports (Mt.)     0.854674
#
#      Missing Values (Var 1)  Missing Values (Var 2)
# 2                         3                       1
# 102                       1                      15
# 150                       4                      23
# 153                       0                       0
# 159                       0                       0
# 163                       0                       0
# 170                       0                       0
# 180                       0                       0
# 184                       0                       0
# 191                       0                       0
# 229                       1                       1
# 235                      22                      79
# 281                       0                       0
# 362                      24                      33

# %%
columns_of_interest = ['Domestic Scrap (DDP Jiangsu incl. VAT $/t)', 'RM Cost \r\n($/t)', 'Exports \r\n(Mnt)', 'Net Exports (Mnt)']

# Calculate max, min, and mean for the selected columns
stats = df[columns_of_interest].agg(['max', 'min', 'mean', 'median'])

stats
# Out:
#         Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost \r\n($/t)  \
# max                                     620.000000         832.000000
# min                                     156.000000         141.000000
# mean                                    390.720524         360.366812
# median                                  388.000000         338.000000
#
#         Exports \r\n(Mnt)  Net Exports (Mnt)
# max             11.000000          11.000000
# min              1.000000          -1.000000
# mean             5.802632           4.592105
# median           5.000000           4.000000

# %%
cols_to_drop = ['Iron Ore \r\n(CFR, $/t)', 'HCC \r\n(Aus FOB, $/t)', 'Domestic Scrap (DDP Jiangsu incl. VAT $/t).1', 
                'Net Exports (Mnt)', 'ACSU \r\n(Mnt)', 'Monthly Iron ore Imports (Mt.)',
                "Stocks of iron ore at China's seaport (Mt.)",
                'YTD Growth rate of  Investment  (Fixed asset investment)',
                'Floor space under construction (y-o-y)']

df.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# ### Total Number of Independent Variables (Factors to be Used for Prediction)

# %%
print(df.loc[:, df.columns.difference(['Month_Dt', 'Month', 'Year', 'HRC \n(FOB, $/t)'])].columns)
len(df.loc[:, df.columns.difference(['Month_Dt', 'Month', 'Year', 'HRC \n(FOB, $/t)'])].columns)
# Out:
# Index(['Air Conditioner (y-o-y)', 'Automobile Production (y-o-y)',
#        'CS Production (Mnt)', 'Civil Metal-Vessels/Steel Ships (y-o-y)',
#        'Cummulative FAI growth (%)',
#        'Domestic Scrap (DDP Jiangsu incl. VAT $/t)',
#        'Export as % of Production', 'Exports \r\n(Mnt)',
#        'Fixed asset investment in real estate development in urban areas (y-o-y )Growth',
#        'HRC \r\n(FOB, $/t)', 'HRC - RM \r\nSpread ($/t)',
#        'Household Fridges (y-o-y)', 'Imports \r\n(Mnt)',
#        'Manufacturing PMI for steel',
#        'Monthly Export of semis & finished steel (Mt.)',
#        'Monthly Imports of semis & finished steel (Mt.)',
#        'Monthly Iron ore Production (Mt.)', 'RM Cost \r\n($/t)',
#        'YTD Iron ore Imports (Mt.)', 'YTD Iron ore Production (Mt.)'],
#       dtype='object')
# 20

# %%
df.to_csv('../data/processed/after_drop_cols.csv', index=False)

# %% [markdown]
# ### Fill NaN Values with their Succeeding Values
# As the values before September 2006 for columns in Data 2 are not collected, the missing data is not random, hence we are not imputing them with the succeeding values as advised by the project owner.

# %%
mask = df['Month_Dt'] > '2006-08-01'

# For rows after 'Aug-06', fill missing values with the previous row's value
df.loc[mask] = df.loc[mask].fillna(method='bfill')
df.head(20)
# Out:
#      Month_Dt  Month  Year  HRC \r\n(FOB, $/t)  \
# 0  2006-01-01      1  2006                 388
# 1  2006-02-01      2  2006                 388
# 2  2006-03-01      3  2006                 449
# 3  2006-04-01      4  2006                 478
# 4  2006-05-01      5  2006                 505
# 5  2006-06-01      6  2006                 559
# 6  2006-07-01      7  2006                 540
# 7  2006-08-01      8  2006                 495
# 8  2006-09-01      9  2006                 472
# 9  2006-10-01     10  2006                 477
# 10 2006-11-01     11  2006                 470
# 11 2006-12-01     12  2006                 470
# 12 2007-01-01      1  2007                 470
# 13 2007-02-01      2  2007                 481
# 14 2007-03-01      3  2007                 560
# 15 2007-04-01      4  2007                 562
# 16 2007-05-01      5  2007                 591
# 17 2007-06-01      6  2007                 572
# 18 2007-07-01      7  2007                 526
# 19 2007-08-01      8  2007                 536
#
#     Domestic Scrap (DDP Jiangsu incl. VAT $/t)  RM Cost \r\n($/t)  \
# 0                                          248                200
# 1                                          248                202
# 2                                          251                205
# 3                                          257                207
# 4                                          263                205
# 5                                          266                205
# 6                                          244                208
# 7                                          253                212
# 8                                          252                211
# 9                                          260                185
# 10                                         262                182
# 11                                         270                188
# 12                                         273                197
# 13                                         288                199
# 14                                         295                203
# 15                                         303                219
# 16                                         306                226
# 17                                         314                228
# 18                                         340                242
# 19                                         349                260
#
#     HRC - RM \r\nSpread ($/t)  CS Production (Mnt)  Exports \r\n(Mnt)  \
# 0                         187                 30.0                2.0
# 1                         185                 30.0                2.0
# 2                         244                 33.0                3.0
# 3                         271                 35.0                3.0
# 4                         300                 36.0                4.0
# 5                         354                 37.0                5.0
# 6                         332                 36.0                4.0
# 7                         283                 37.0                5.0
# 8                         261                 36.0                5.0
# 9                         292                 38.0                5.0
# 10                        288                 38.0                6.0
# 11                        282                 39.0                6.0
# 12                        273                 38.0                5.0
# 13                        282                 36.0                5.0
# 14                        357                 40.0                6.0
# 15                        342                 41.0                8.0
# 16                        365                 42.0                7.0
# 17                        344                 43.0                7.0
# 18                        284                 42.0                7.0
# 19                        275                 42.0                6.0
#
#     Imports \r\n(Mnt)  Export as % of Production  Cummulative FAI growth (%)  \
# 0                 2.0                        7.0                        26.6
# 1                 1.0                        7.0                        26.6
# 2                 2.0                        9.0                        29.8
# 3                 2.0                        9.0                        29.6
# 4                 2.0                       12.0                        30.3
# 5                 2.0                       15.0                        31.3
# 6                 2.0                       12.0                        30.5
# 7                 2.0                       14.0                        29.1
# 8                 2.0                       14.0                        28.2
# 9                 1.0                       14.0                        26.8
# 10                2.0                       16.0                        26.6
# 11                2.0                       15.0                        24.5
# 12                2.0                       13.0                        23.4
# 13                1.0                       13.0                        23.4
# 14                2.0                       15.0                        25.3
# 15                2.0                       20.0                        25.5
# 16                1.0                       17.0                        25.9
# 17                1.0                       17.0                        26.7
# 18                1.0                       16.0                        26.6
# 19                1.0                       14.0                        26.7
#
#     Monthly Imports of semis & finished steel (Mt.)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                              1.61
# 9                                              1.42
# 10                                             1.45
# 11                                             1.53
# 12                                             1.53
# 13                                             1.28
# 14                                             1.61
# 15                                             1.66
# 16                                             1.41
# 17                                             1.44
# 18                                             1.42
# 19                                             1.49
#
#     Monthly Export of semis & finished steel (Mt.)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                             5.14
# 9                                             5.19
# 10                                            6.11
# 11                                            6.05
# 12                                            4.95
# 13                                            4.92
# 14                                            6.04
# 15                                            8.03
# 16                                            7.14
# 17                                            7.10
# 18                                            6.81
# 19                                            5.72
#
#     YTD Iron ore Imports (Mt.)  YTD Iron ore Production (Mt.)  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# 5                          NaN                            NaN
# 6                          NaN                            NaN
# 7                          NaN                            NaN
# 8                       247.20                         405.80
# 9                       297.69                         462.30
# 10                      297.69                         521.50
# 11                      326.30                         588.20
# 12                      133.55                         252.28
# 13                      133.55                         252.28
# 14                      133.55                         252.28
# 15                      133.55                         252.28
# 16                      161.17                         252.28
# 17                      187.92                         321.29
# 18                      221.52                         380.42
# 19                      250.81                         442.17
#
#     Monthly Iron ore Production (Mt.)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                               56.50
# 9                               56.50
# 10                              59.20
# 11                              66.70
# 12                              69.01
# 13                              69.01
# 14                              69.01
# 15                              69.01
# 16                              69.01
# 17                              69.01
# 18                              59.13
# 19                              61.75
#
#     Fixed asset investment in real estate development in urban areas (y-o-y )Growth  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                24.3
# 9                                                24.1
# 10                                               24.0
# 11                                               21.8
# 12                                               24.3
# 13                                               24.3
# 14                                               26.9
# 15                                               27.4
# 16                                               27.5
# 17                                               28.5
# 18                                               28.9
# 19                                               29.0
#
#     Automobile Production (y-o-y)  Civil Metal-Vessels/Steel Ships (y-o-y)  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# 5                             NaN                                      NaN
# 6                             NaN                                      NaN
# 7                             NaN                                      NaN
# 8                            24.0                                      6.0
# 9                            25.1                                     11.4
# 10                           26.1                                      8.3
# 11                           27.0                                     13.1
# 12                           45.0                                      8.6
# 13                           21.5                                      8.6
# 14                           22.3                                      8.6
# 15                           21.4                                     23.0
# 16                           22.0                                     24.0
# 17                           22.9                                     20.8
# 18                           24.3                                     21.7
# 19                           24.0                                     27.8
#
#     Household Fridges (y-o-y)  Air Conditioner (y-o-y)  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                         NaN                      NaN
# 8                        34.2                      3.9
# 9                        31.8                      6.7
# 10                       28.9                      7.2
# 11                       15.8                     16.1
# 12                       15.8                     16.1
# 13                       15.8                     16.1
# 14                       15.8                     16.1
# 15                       15.8                     17.9
# 16                       15.8                     19.7
# 17                       15.8                     23.3
# 18                       15.8                     25.7
# 19                       15.8                     24.4
#
#     Manufacturing PMI for steel
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                          51.7
# 9                          55.9
# 10                         54.9
# 11                         50.1
# 12                         55.4
# 13                         60.3
# 14                         54.2
# 15                         55.8
# 16                         60.1
# 17                         54.4
# 18                         54.7
# 19                         55.9

# %%
df.to_csv('../data/processed/after_fillna.csv')

# %% [markdown]
# For model testing purpose, we drop all the rows with NaN values to avoid potential errors.

# %%
df_wo_na = df.dropna()
df_wo_na.to_csv('../data/final/wo_na.csv')

# %% [markdown]
# EDA (TINA)
# Line plots for trends, box plots for seasonality

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter

df=pd.read_excel('China HRC Price Model Data 1 (3).xlsx',sheet_name='Edited Combined Data')


dates_ls=df['Month'].tolist()

columns_all=df.columns.tolist()
columns_to_keep=columns_all[:14]
df=df[columns_to_keep]
df.iloc[:,1:]=df.iloc[:,1:].fillna(df.iloc[:,1:].mean())


plt.rcParams.update({'font.size':20})
plt.figure(figsize=(12,8),dpi=50)
plt.plot(df['Month'],df[columns_all[1]],color='#d07d76',linestyle='-',label='Price Trend')
plt.title("HRC (FOB) Trend")
plt.xlabel("Month")
plt.ylabel("Price ($/t)")
plt.xticks(rotation=0)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()




df['Month_num']=df['Month'].dt.month
plt.figure(figsize=(12,8),dpi=50)
sns.boxplot(x='Month_num',y=columns_all[1],data=df)
plt.title("Box Plot of HRC Prices")
plt.xlabel("Month")
plt.ylabel("Price ($/t)")
plt.xticks(ticks=range(12),labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.tight_layout()
plt.show()

# %% [markdown]
# LSTM (doesn't need stationary data) - machine learning model (TINA)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import optuna
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings('ignore')
df=df.drop('Month_num',axis=1)
df=df.iloc[:,1:]
target=df.iloc[:,0].values
features=df.iloc[:,1:].values
scaler=MinMaxScaler()
features_scaled=scaler.fit_transform(features)
def create_dataset(features,target,time_steps=1):
    X,y=[],[]
    for i in range(len(features)-time_steps):
        X.append(features[i:(i+time_steps)])
        y.append(target[i+time_steps])
    return np.array(X),np.array(y)
def create_lstm_model(input_shape,n_units,learning_rate,dropout_rate):
    model=Sequential()
    model.add(LSTM(units=n_units,input_shape=input_shape,return_sequences=False))
    model.add(Dense(1))
    optimizer=Adam(learning_rate=learning_rate)
    model.compile(loss='mse',optimizer=optimizer)
    return model
def objective(trial):
    learning_rate=trial.suggest_loguniform('learning_rate',1e-5,1e-2)
    n_units=trial.suggest_int('n_units',32,128)
    dropout_rate=trial.suggest_uniform('dropout_rate',0.0,0.5)
    time_steps=trial.suggest_int('time_steps',1,30)
    X,y=create_dataset(features_scaled,target,time_steps)
    train_size=int(len(X) * 0.8)
    X_train,X_val=X[:train_size],X[train_size:]
    y_train,y_val=y[:train_size],y[train_size:]
    input_shape=(X_train.shape[1],X_train.shape[2])
    model=create_lstm_model(input_shape,n_units,learning_rate,dropout_rate)
    model.fit(X_train,y_train,epochs=10,batch_size=64,validation_data=(X_val,y_val),verbose=0)
    val_loss=model.evaluate(X_val,y_val,verbose=0)
    return val_loss
study=optuna.create_study(direction='minimize')
study.optimize(objective,n_trials=20)
print(f"Best trial:{study.best_trial.params}")
print(f"Best validation loss:{study.best_value}")
best_params=study.best_trial.params
X,y=create_dataset(features_scaled,target,best_params['time_steps'])
train_size=int(len(X) * 0.8)
X_train,X_val=X[:train_size],X[train_size:]
y_train,y_val=y[:train_size],y[train_size:]
input_shape=(X_train.shape[1],X_train.shape[2])
best_model=create_lstm_model(input_shape,best_params['n_units'],best_params['learning_rate'],best_params['dropout_rate'])
best_model.fit(X_train,y_train,epochs=1000,batch_size=128,validation_data=(X_val,y_val))
final_loss=best_model.evaluate(X_val,y_val)
print(f"Final model validation loss:{final_loss}")
# Out:
# [I 2025-03-01 22:18:24,724] A new study created in memory with name: no-name-db14f3e1-e7c8-460a-9465-9a4380d8b4e6
# [I 2025-03-01 22:18:26,507] Trial 0 finished with value: 417560.03125 and parameters: {'learning_rate': 0.0001760582328845162, 'n_units': 55, 'dropout_rate': 0.2521303202995203, 'time_steps': 9}. Best is trial 0 with value: 417560.03125.
# [I 2025-03-01 22:18:28,392] Trial 1 finished with value: 363617.25 and parameters: {'learning_rate': 0.008996669246652501, 'n_units': 83, 'dropout_rate': 0.1148932361170909, 'time_steps': 19}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:30,107] Trial 2 finished with value: 426276.8125 and parameters: {'learning_rate': 0.0012124803771716764, 'n_units': 32, 'dropout_rate': 0.24576943999698514, 'time_steps': 5}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:32,071] Trial 3 finished with value: 375725.96875 and parameters: {'learning_rate': 0.0006262499279038478, 'n_units': 127, 'dropout_rate': 0.27682481267429415, 'time_steps': 28}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:33,922] Trial 4 finished with value: 387421.78125 and parameters: {'learning_rate': 4.397775665911765e-05, 'n_units': 82, 'dropout_rate': 0.3643051359052508, 'time_steps': 28}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:35,655] Trial 5 finished with value: 426364.9375 and parameters: {'learning_rate': 0.000449401840935786, 'n_units': 123, 'dropout_rate': 0.4229715338288641, 'time_steps': 4}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:37,478] Trial 6 finished with value: 387410.0 and parameters: {'learning_rate': 5.705496187465149e-05, 'n_units': 55, 'dropout_rate': 0.21681805989654795, 'time_steps': 27}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:39,209] Trial 7 finished with value: 429423.71875 and parameters: {'learning_rate': 8.900706338162999e-05, 'n_units': 112, 'dropout_rate': 0.44158639215824386, 'time_steps': 6}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:40,994] Trial 8 finished with value: 408298.0 and parameters: {'learning_rate': 3.317275298274842e-05, 'n_units': 76, 'dropout_rate': 0.4942291682764803, 'time_steps': 17}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:42,792] Trial 9 finished with value: 416984.3125 and parameters: {'learning_rate': 8.9959387465243e-05, 'n_units': 107, 'dropout_rate': 0.4547539461581412, 'time_steps': 13}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:44,655] Trial 10 finished with value: 364521.59375 and parameters: {'learning_rate': 0.007325457190433869, 'n_units': 89, 'dropout_rate': 0.026612410534814418, 'time_steps': 20}. Best is trial 1 with value: 363617.25.
# [I 2025-03-01 22:18:46,471] Trial 11 finished with value: 359587.4375 and parameters: {'learning_rate': 0.009139596981493974, 'n_units': 89, 'dropout_rate': 0.013770472225949248, 'time_steps': 20}. Best is trial 11 with value: 359587.4375.
# [I 2025-03-01 22:18:48,312] Trial 12 finished with value: 361740.875 and parameters: {'learning_rate': 0.00790362375691576, 'n_units': 93, 'dropout_rate': 0.016152838844283524, 'time_steps': 22}. Best is trial 11 with value: 359587.4375.
# [I 2025-03-01 22:18:50,193] Trial 13 finished with value: 376856.5 and parameters: {'learning_rate': 0.0026640570082127344, 'n_units': 99, 'dropout_rate': 0.04201230065779828, 'time_steps': 23}. Best is trial 11 with value: 359587.4375.
# [I 2025-03-01 22:18:51,990] Trial 14 finished with value: 373200.59375 and parameters: {'learning_rate': 0.002778064161477037, 'n_units': 63, 'dropout_rate': 0.1191196851011782, 'time_steps': 24}. Best is trial 11 with value: 359587.4375.
# [I 2025-03-01 22
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 40321.6836 - val_loss: 60295.8828
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 41461.5742 - val_loss: 59998.3867
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 40402.8086 - val_loss: 59705.8281
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 38605.8477 - val_loss: 59414.6797
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 37381.3828 - val_loss: 59118.9219
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 40708.4805 - val_loss: 58824.7383
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 37671.8125 - val_loss: 58537.1719
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 39993.6406 - val_loss: 58249.6602
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 37634.4883 - val_loss: 57965.4766
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 36543.8633 - val_loss: 57680.3164
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 37859.5977 - val_loss: 57394.1133
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 38318.4648 - val_loss: 57110.5664
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 38572.8320 - val_loss: 56829.1953
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 37098.2500 - val_loss: 56551.3438
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 38876.0078 - val_loss: 56276.9531
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 38214.3320 - val_loss: 56006.5117
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 37559.1133 - val_loss: 55738.4219
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 38665.4883 - val_loss: 55471.4453
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 36179.5352 - val_loss: 55207.2500
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 37203.7969 - val_loss: 54942.8516
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 37632.8867 - val_loss: 54681.1953
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 37542.8164 - val_loss: 54422.6719
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 36325.4883 - val_loss: 54167.5703
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 34989.3477 - val_loss: 53912.9414
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 35305.3672 - val_loss: 53657.4570
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 35379.6133 - val_loss: 53401.8047
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 36411.9375 - val_loss: 53147.4570
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 34489.7109 - val_loss: 52893.6719
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 34277.8594 - val_loss: 52638.6250
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 35729.5508 - val_loss: 52386.2734
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 36033.4258 - val_loss: 52140.6953
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 33867.8555 - val_loss: 51898.0898
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 34495.6562 - val_loss: 51653.7266
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 33578.6172 - val_loss: 51410.7305
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 34140.5195 - val_loss: 51169.3516
# Epoch 371/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 33465.8242 - val_loss: 50929.2266
# Epoch 372/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 34527.9297 - val_loss: 50691.0820
# Epoch 373/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 32123.3125 - val_loss: 50455.2930
# Epoch 374/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 34495.5469 - val_loss: 50220.7422
# Epoch 375/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 34705.3555 - val_loss: 49992.8203
# Epoch 376/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 31601.9980 - val_loss: 49769.5742
# Epoch 377/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 31885.2051 - val_loss: 49544.0625
# Epoch 378/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 33161.3789 - val_loss: 49319.1328
# Epoch 379/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 30996.0488 - val_loss: 49096.3594
# Epoch 380/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 32569.3086 - val_loss: 48869.7930
# Epoch 381/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 33542.1562 - val_loss: 48646.0195
# Epoch 382/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 31539.6309 - val_loss: 48426.6055
# Epoch 383/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 32524.7285 - val_loss: 48207.6953
# Epoch 384/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 30914.3145 - val_loss: 47990.8828
# Epoch 385/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 31524.8613 - val_loss: 47774.3086
# Epoch 386/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 31432.8809 - val_loss: 47559.8750
# Epoch 387/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 30876.2090 - val_loss: 47345.4648
# Epoch 388/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 31761.0977 - val_loss: 47131.6836
# Epoch 389/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 31076.4414 - val_loss: 46922.2812
# Epoch 390/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 32922.6016 - val_loss: 46716.5547
# Epoch 391/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 30601.8027 - val_loss: 46514.7422
# Epoch 392/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 29886.5117 - val_loss: 46310.7773
# Epoch 393/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 31970.5762 - val_loss: 46106.3242
# Epoch 394/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 31674.3359 - val_loss: 45908.4180
# Epoch 395/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 30180.8535 - val_loss: 45714.8477
# Epoch 396/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 30857.4727 - val_loss: 45521.0547
# Epoch 397/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 30335.0156 - val_loss: 45329.5781
# Epoch 398/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 31639.7656 - val_loss: 45138.9102
# Epoch 399/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 29436.7344 - val_loss: 44950.4023
# Epoch 400/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 29156.3828 - val_loss: 44760.4375
# Epoch 401/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 31662.1406 - val_loss: 44571.6953
# Epoch 402/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 30337.7793 - val_loss: 44388.7891
# Epoch 403/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 28380.5273 - val_loss: 44208.1758
# Epoch 404/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 29353.4863 - val_loss: 44025.0000
# Epoch 405/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 30116.9258 - val_loss: 43841.2617
# Epoch 406/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 30374.8867 - val_loss: 43660.3008
# Epoch 407/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 30757.7207 - val_loss: 43482.4648
# Epoch 408/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 29188.2246 - val_loss: 43308.3047
# Epoch 409/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 30208.7188 - val_loss: 43134.5078
# Epoch 410/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 30204.1504 - val_loss: 42964.9062
# Epoch 411/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 29460.2109 - val_loss: 42796.7773
# Epoch 412/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 28563.7734 - val_loss: 42627.9688
# Epoch 413/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 28924.5469 - val_loss: 42459.7891
# Epoch 414/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 27557.6914 - val_loss: 42293.1953
# Epoch 415/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 28535.1094 - val_loss: 42124.4375
# Epoch 416/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 28371.4180 - val_loss: 41955.5938
# Epoch 417/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 27658.3809 - val_loss: 41787.5117
# Epoch 418/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 27479.6230 - val_loss: 41619.7266
# Epoch 419/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 28846.0605 - val_loss: 41453.5195
# Epoch 420/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 27748.9199 - val_loss: 41289.5547
# Epoch 421/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 27773.8867 - val_loss: 41124.3320
# Epoch 422/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 28199.3555 - val_loss: 40959.4883
# Epoch 423/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 27685.6426 - val_loss: 40796.2266
# Epoch 424/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 27921.7090 - val_loss: 40634.2109
# Epoch 425/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 27811.8965 - val_loss: 40474.9688
# Epoch 426/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 28640.9512 - val_loss: 40317.6172
# Epoch 427/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 27477.1816 - val_loss: 40164.9492
# Epoch 428/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 26907.6172 - val_loss: 40012.8750
# Epoch 429/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 27908.7012 - val_loss: 39861.3555
# Epoch 430/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 27230.7559 - val_loss: 39711.4141
# Epoch 431/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 27665.0156 - val_loss: 39560.6523
# Epoch 432/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 27815.6973 - val_loss: 39410.5859
# Epoch 433/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 25985.8906 - val_loss: 39262.5078
# Epoch 434/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 27431.9082 - val_loss: 39114.2812
# Epoch 435/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 27376.4414 - val_loss: 38967.5312
# Epoch 436/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 27314.5566 - val_loss: 38824.8203
# Epoch 437/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 26636.9492 - val_loss: 38685.7070
# Epoch 438/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 27676.5547 - val_loss: 38547.6016
# Epoch 439/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 26064.0176 - val_loss: 38409.4688
# Epoch 440/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 27483.2949 - val_loss: 38271.8555
# Epoch 441/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 26714.0352 - val_loss: 38137.5977
# Epoch 442/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss:
1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 20318.9102 - val_loss: 22176.7168
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 20815.4082 - val_loss: 22176.3027
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 20297.8398 - val_loss: 22178.1484
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 20532.5039 - val_loss: 22178.4590
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 20041.1445 - val_loss: 22176.5547
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 20273.0156 - val_loss: 22173.5684
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 21322.9707 - val_loss: 22172.3770
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 21479.6719 - val_loss: 22174.7227
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 19999.6484 - val_loss: 22179.7715
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 20301.4238 - val_loss: 22186.3066
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 20570.5703 - val_loss: 22194.7539
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 20654.4336 - val_loss: 22201.6270
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 19660.5742 - val_loss: 22206.1406
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 20734.1992 - val_loss: 22206.2402
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 21690.4082 - val_loss: 22205.5527
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 24060.8730
# Final model validation loss:22205.552734375

# %%
df['Date']=dates_ls

unscaled_data = scaler.inverse_transform(features_scaled)
future_prices=[]
last_sequence=unscaled_data[-best_params['time_steps']:].copy()
for a in range(30):
    last_sequence_expanded=np.expand_dims(last_sequence,axis=0)
    future_prediction=best_model.predict(last_sequence_expanded)
    future_price_scaled=future_prediction[0][0]
    real_future_price=0.001*(future_price_scaled*(target.max())+target.min())
    future_prices.append(real_future_price)
    new_row=np.append(future_price_scaled,last_sequence[-1,1:])
    last_sequence=np.vstack((last_sequence[1:],new_row))
for x,price in enumerate(future_prices,1):
    print(f"predict future price：{price}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predict future price：501.6154740814209
# predict future price：518.3776505569458
# predict future price：521.2186745361329
# predict future price：521.6679049972535
# predict future price：521.7318251327515
# predict future price：521.7408040908814
# predict future price：521.7420912841798
# predict future price：521.7421540740967
# predict future price：521.7378843597412
# predict future price：521.5066290954591
# predict future price：515.1923494628907
# predict future price：508.88227675476077
# predict future price：508.6541609863282
# predict future price：508.6498912719727
# predict future price：508.6497029022217
# predict future price：508.6492005828858
# predict future price：508.6454331878662
# predict future price：508.61818236389166
# predict future price：508.41694067993166
# predict future price：507.01842085876467
# predict future price：502.21254340209964
# predict future price：502.22127120056155
# predict future price：502.2289943603516
# predict future price：502.2367175201416
# predict future price：502.2444406799317
# predict future price：502.25216383972173
# predict future price：502.25982420959474
# predict future price：502.2672334197998
# predict future price：502.274014730835
# predict future price：502.2794774536133

# %%
future_dates=pd.date_range(start=df['Date'].iloc[-1],periods=31,freq='MS')[1:]
df['Year-Month']=df['Date'].dt.strftime('%Y-%m')
future_dates_str=future_dates.strftime('%Y-%m')
df['Year-Month']=df['Year-Month'].astype(str)
future_dates_str=future_dates_str.astype(str)
all_dates=list(df['Year-Month'])+list(future_dates_str)
plt.figure(figsize=(12,8))
plt.plot(df['Year-Month'],target,label="Historical Prices",color='#506551')
plt.plot(future_dates_str,future_prices,label="Predicted Prices",color='#a44f56',linestyle="--")
plt.xlabel("Year-Month")
plt.ylabel("Price")
plt.title("Historical vs. Predicted Prices")
plt.xticks(rotation=45)
plt.xticks(all_dates[::30],rotation=90)
plt.legend()
plt.grid(True)
plt.show()
